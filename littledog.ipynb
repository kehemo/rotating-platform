# %% [markdown]
# This notebook provides examples to go along with the [textbook](http://underactuated.csail.mit.edu/humanoids.html).  I recommend having both windows open, side-by-side!
#
# [Click here](http://underactuated.csail.mit.edu/drake.html#notebooks) for instructions on how to run the notebook on Deepnote and/or Google Colab.

# %%
from functools import partial

import numpy as np
from pydrake.all import (AddMultibodyPlantSceneGraph,
                         AddUnitQuaternionConstraintOnPlant, AutoDiffXd,
                         DiagramBuilder, ExtractGradient, ExtractValue,
                         InitializeAutoDiff, JacobianWrtVariable, JointIndex,
                         MathematicalProgram, MeshcatVisualizerCpp,
                         MultibodyPlant, OrientationConstraint, Parser,
                         PidController, PiecewisePolynomial,
                         PositionConstraint, RigidTransform, RotationMatrix,
                         Simulator, SnoptSolver, Solve, StartMeshcat, eq,
                         namedview, set_log_level, Linearize, LinearQuadraticRegulator)

from underactuated import FindResource, running_as_notebook

set_log_level('off');

# %%
# Start the visualizer (run this cell only once, each instance consumes a port)
meshcat = StartMeshcat()
# Out:
# Installing NginX server for MeshCat on Deepnote...
# Meshcat URL: <a href='https://62851c10-b5c1-4bff-87dc-84099c2e318d.deepnoteproject.com/7000/' target='_blank'>https://62851c10-b5c1-4bff-87dc-84099c2e318d.deepnoteproject.com/7000/</a>

# %% [markdown]
# # The LittleDog Robot
#
# [LittleDog](https://www.youtube.com/watch?v=QID_czp_fRg) is a robot built by BostonDynamics, programmed by teams competing in the DARPA Learning Locomotion program.
#
# # Simulation: Standing with PID Control

# %%
def set_home(plant, context):
    # NOTE: this is not the set_home used in the traj optimization
    hip_roll = .1;
    hip_pitch = 1;
    knee = 1.55;
    plant.GetJointByName("front_right_hip_roll").set_angle(context, -hip_roll)
    plant.GetJointByName("front_right_hip_pitch").set_angle(context, hip_pitch)
    plant.GetJointByName("front_right_knee").set_angle(context, -knee)
    plant.GetJointByName("front_left_hip_roll").set_angle(context, hip_roll)
    plant.GetJointByName("front_left_hip_pitch").set_angle(context, hip_pitch)
    plant.GetJointByName("front_left_knee").set_angle(context, -knee)
    plant.GetJointByName("back_right_hip_roll").set_angle(context, -hip_roll)
    plant.GetJointByName("back_right_hip_pitch").set_angle(context, -hip_pitch)
    plant.GetJointByName("back_right_knee").set_angle(context, knee)
    plant.GetJointByName("back_left_hip_roll").set_angle(context, hip_roll)
    plant.GetJointByName("back_left_hip_pitch").set_angle(context, -hip_pitch)
    plant.GetJointByName("back_left_knee").set_angle(context, knee)
    plant.SetFreeBodyPose(context, plant.GetBodyByName("body"), RigidTransform([0, 0, 1.146]))

def run_pid_control():
    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, 1e-4)
    parser = Parser(plant)
    parser.AddModelFromFile(FindResource('models/littledog/LittleDog.urdf'))
    parser.AddModelFromFile('./ground.urdf')
    plant.Finalize()

    # Add a PD Controller
    kp = 1*np.ones(12)
    ki = 0.0*np.ones(12)
    kd = .1*np.ones(12)
    # Select the joint states (and ignore the floating-base states)
    S = np.zeros((24, 39))
    j = 0
    for i in range(plant.num_joints()):
        joint = plant.get_joint(JointIndex(i))
        print(joint.name(), joint.velocity_start(), joint.num_velocities())
        if joint.num_positions() != 1:
            continue
        if "rot1" in joint.name():
            continue
        S[j, joint.position_start()] = 1
        S[12+j, joint.velocity_start()] = 1
        # use lower gain for the knee joints
        if "knee" in joint.name():
            kd[j] = 0.1
        j = j+1
    print(plant.MakeActuationMatrix()[7:,:].T.shape)

    control = builder.AddSystem(PidController(
        kp=kp, ki=ki, kd=kd,
        state_projection=S,
        output_projection=plant.MakeActuationMatrix()[7:,:].T))

    builder.Connect(plant.get_state_output_port(), control.get_input_port_estimated_state())
    builder.Connect(control.get_output_port(), plant.get_actuation_input_port())

    visualizer = MeshcatVisualizerCpp.AddToBuilder(builder, scene_graph,
                                                   meshcat)

    diagram = builder.Build()
    simulator = Simulator(diagram)
    context = simulator.get_mutable_context()
    plant_context = plant.GetMyContextFromRoot(context)

    print(type(plant_context.get_mutable_discrete_state_vector()))
    print(type(plant.get_state_output_port().Eval(plant_context)))
    print(plant_context.get_mutable_discrete_state_vector())
    print(plant.get_state_output_port().Eval(plant_context))
    set_home(plant, plant_context)

    print(plant.get_state_output_port().Eval(plant_context))
    x0 = S @ plant.get_state_output_port().Eval(plant_context)
    print(x0)
    control.get_input_port_desired_state().FixValue(
        control.GetMyContextFromRoot(context), x0)

    simulator.set_target_realtime_rate(1.0 if running_as_notebook else 0)
    visualizer.StartRecording()
    simulator.AdvanceTo(3)
    visualizer.PublishRecording()

# run_pid_control()

# %% [markdown]
# ok now do the actual thing
#
# we start by just trying to simulate physics (including the bridge)

# %%
# TODO (kenneth): allow kinetic friction, stop relying on pre-specified mode sequence

def set_home(plant, context, ground_angle):
    # used in traj optimization for setting initial quess positions
    hip_roll = .1;
    hip_pitch = 1;
    knee = 1.55;
    plant.GetJointByName("front_right_hip_roll").set_angle(context, -hip_roll)
    plant.GetJointByName("front_right_hip_pitch").set_angle(context, hip_pitch)
    plant.GetJointByName("front_right_knee").set_angle(context, -knee)
    plant.GetJointByName("front_left_hip_roll").set_angle(context, hip_roll)
    plant.GetJointByName("front_left_hip_pitch").set_angle(context, hip_pitch)
    plant.GetJointByName("front_left_knee").set_angle(context, -knee)
    plant.GetJointByName("back_right_hip_roll").set_angle(context, -hip_roll)
    plant.GetJointByName("back_right_hip_pitch").set_angle(context, -hip_pitch)
    plant.GetJointByName("back_right_knee").set_angle(context, knee)
    plant.GetJointByName("back_left_hip_roll").set_angle(context, hip_roll)
    plant.GetJointByName("back_left_hip_pitch").set_angle(context, -hip_pitch)
    plant.GetJointByName("back_left_knee").set_angle(context, knee)
    plant.SetFreeBodyPose(context, plant.GetBodyByName("body"), RigidTransform([0, 0, 1.346]))
    # plant.SetFreeBodyPose(context, plant.GetBodyByName("body"), RigidTransform([0, 0, 0.146]))
    plant.GetJointByName("rot1").set_angle(context, ground_angle)

# Need this because a==b returns True even if a = AutoDiffXd(1, [1, 2]), b= AutoDiffXd(2, [3, 4])
# That's the behavior of AutoDiffXd in C++, also.
def autoDiffArrayEqual(a,b):
    return np.array_equal(a, b) and np.array_equal(ExtractGradient(a), ExtractGradient(b))

# TODO: promote this to drake (and make a version with model_instance)
def MakeNamedViewPositions(mbp, view_name):
    names = [None]*mbp.num_positions()
    print("Entering MakeNamedViewPositions")
    for ind in range(mbp.num_joints()):
        joint = mbp.get_joint(JointIndex(ind))
        if joint.num_positions() == 0:
            # skip weld joints
            continue
        print('joint name', joint.name(), 'joint.num_positions', joint.num_positions())
        # TODO: Handle planar joints, etc.
        # assert(joint.num_positions() == 1)
        names[joint.position_start()] = joint.name()
    
    for ind in mbp.GetFloatingBaseBodies():
        body = mbp.get_body(ind)
        start = body.floating_positions_start()
        body_name = body.name()
        names[start] = body_name+'_qw'
        names[start+1] = body_name+'_qx'
        names[start+2] = body_name+'_qy'
        names[start+3] = body_name+'_qz'
        names[start+4] = body_name+'_x'
        names[start+5] = body_name+'_y'
        names[start+6] = body_name+'_z'
    print("Exiting MakeNamedViewPositions")
    return namedview(view_name, names)

def MakeNamedViewVelocities(mbp, view_name):
    names = [None]*mbp.num_velocities()
    for ind in range(mbp.num_joints()):
        joint = mbp.get_joint(JointIndex(ind))
        if joint.num_positions() == 0:
            # skip weld joints
            continue
        # print('joint name', joint.name(), 'joint.num_positions', joint.num_positions())
        # TODO: Handle planar joints, etc.
        # assert(joint.num_velocities() == 1)
        names[joint.velocity_start()] = joint.name()
    for ind in mbp.GetFloatingBaseBodies():
        body = mbp.get_body(ind)
        start = body.floating_velocities_start() - mbp.num_positions()
        body_name = body.name()
        names[start] = body_name+'_wx'
        names[start+1] = body_name+'_wy'
        names[start+2] = body_name+'_wz'
        names[start+3] = body_name+'_vx'
        names[start+4] = body_name+'_vy'
        names[start+5] = body_name+'_vz'
    return namedview(view_name, names)

def gait_optimization(gait = 'walking_trot', ground_angle=0, initial_guess=None, final=True):
    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, 1e-3)
    parser = Parser(plant)
    littledog = parser.AddModelFromFile(FindResource('models/littledog/LittleDog.urdf'))
    bridge = parser.AddModelFromFile('./ground.urdf')
    plant.Finalize()
    visualizer = MeshcatVisualizerCpp.AddToBuilder(builder, scene_graph,
                                                   meshcat)

    diagram = builder.Build()
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyContextFromRoot(context)
    set_home(plant, plant_context, ground_angle)
    diagram.Publish(context)
    print(plant.CalcCenterOfMassPositionInWorld(plant.CreateDefaultContext(), [littledog]))
    print(plant.GetBodyByName("ground").EvalPoseInWorld(plant_context).rotation().inverse().multiply(np.array([[0.0, 0.0, 1.0]]).T))
    print(np.linalg.inv(plant.GetBodyByName("ground").CalcSpatialInertiaInBodyFrame(plant_context).CalcRotationalInertia().CopyToFullMatrix3()))
    # raise RuntimeError()

    q0 = plant.GetPositions(plant_context)
    print('q0 home positions:', q0)
    body_frame = plant.GetFrameByName("body")

    PositionView = MakeNamedViewPositions(plant, "Positions")
    VelocityView = MakeNamedViewVelocities(plant, "Velocities")

    mu = 1 # rubber on rubber
    total_mass = sum(plant.get_body(index).get_mass(context) for index in plant.GetBodyIndices(littledog))
    gravity = plant.gravity_field().gravity_vector()

    nq = 12
    foot_frame = [
        plant.GetFrameByName('front_left_foot_center'),
        plant.GetFrameByName('front_right_foot_center'),
        plant.GetFrameByName('back_left_foot_center'),
        plant.GetFrameByName('back_right_foot_center')]

    # setup gait
    is_laterally_symmetric = False
    check_self_collision = False
    if gait == 'running_trot':
        N = 21
        in_stance = np.zeros((4, N))
        in_stance[1, 3:17] = 1
        in_stance[2, 3:17] = 1
        speed = 0.9
        stride_length = .55
        is_laterally_symmetric = True
    elif gait == 'walking_trot':
        N = 21
        in_stance = np.zeros((4, N))
        in_stance[0, :11] = 1
        in_stance[1, 8:N] = 1
        in_stance[2, 8:N] = 1
        in_stance[3, :11] = 1
        speed = 0.4
        stride_length = .25
        is_laterally_symmetric = True
    elif gait == 'rotary_gallop':
        N = 41
        in_stance = np.zeros((4, N))
        in_stance[0, 7:19] = 1
        in_stance[1, 3:15] = 1
        in_stance[2, 24:35] = 1
        in_stance[3, 26:38] = 1
        speed = 1
        stride_length = .65
        check_self_collision = True
    elif gait == 'bound':
        N = 41
        in_stance = np.zeros((4, N))
        in_stance[0, 6:18] = 1
        in_stance[1, 6:18] = 1
        in_stance[2, 21:32] = 1
        in_stance[3, 21:32] = 1
        speed = 1.2
        stride_length = .55
        check_self_collision = True
    else:
        raise RuntimeError('Unknown gait.')


    T = stride_length / speed
    if is_laterally_symmetric:
        T = T / 2.0

    prog = MathematicalProgram()

    # Time steps
    h = prog.NewContinuousVariables(N-1, "h")
    prog.AddBoundingBoxConstraint(0.5*T/N, 2.0*T/N, h)
    prog.AddLinearConstraint(sum(h) >= .9*T)
    prog.AddLinearConstraint(sum(h) <= 1.1*T)

    # Create one context per timestep (to maximize cache hits)
    context = [plant.CreateDefaultContext() for i in range(N)]
    # We could get rid of this by implementing a few more Jacobians in MultibodyPlant:
    ad_plant = plant.ToAutoDiffXd()

    # Joint positions and velocities

    # 20 positions - 19 for the dog, 1 for the bridge joint (note that the bridge joint is index 0)
    nq = plant.num_positions()
    # 19 velocities (not sure why there's one less)
    nv = plant.num_velocities()
    q = prog.NewContinuousVariables(nq, N, "q")
    v = prog.NewContinuousVariables(nv, N, "v")

    # for n in range(N):
        
    #     prog.AddLinearConstraint(q[0, n] == 0)
    #     prog.AddLinearConstraint(v[0, n] == 0)

    q_view = PositionView(q)
    print(q_view.get_fields())
    v_view = VelocityView(v)
    q0_view = PositionView(q0)
    # Joint costs
    q_cost = PositionView([1]*nq)
    v_cost = VelocityView([1]*nv)
    q_cost.body_x = 0
    q_cost.body_y = 0
    q_cost.body_qx = 0
    q_cost.body_qy = 0
    q_cost.body_qz = 0
    q_cost.body_qw = 0
    q_cost.front_left_hip_roll = 5
    q_cost.front_right_hip_roll = 5
    q_cost.back_left_hip_roll = 5
    q_cost.back_right_hip_roll = 5
    v_cost.body_vx = 0
    v_cost.body_wx = 0
    v_cost.body_wy = 0
    v_cost.body_wz = 0

    for n in range(N):
        # Joint limits
        # limits are -inf and inf for ind 0 (bridge joint)
        prog.AddBoundingBoxConstraint(plant.GetPositionLowerLimits()[8:], plant.GetPositionUpperLimits()[8:], q[8:,n])
        # Joint velocity limits
        prog.AddBoundingBoxConstraint(plant.GetVelocityLowerLimits()[8:], plant.GetVelocityUpperLimits()[8:], v[8:,n])
        # Unit quaternions
        AddUnitQuaternionConstraintOnPlant(plant, q[:,n], prog)
        # Body orientation
        # prog.AddConstraint(OrientationConstraint(plant,
        #                                          body_frame, RotationMatrix(),
        #                                          plant.world_frame(), RotationMatrix(),
        #                                          0.1, context[n]), q[:,n])
        # Initial guess for all joint angles is the home position
        prog.SetInitialGuess(q[:,n], q0)  # Solvers get stuck if the quaternion is initialized with all zeros.

        # Running costs:
        prog.AddQuadraticErrorCost(np.diag(q_cost), q0, q[:,n])
        prog.AddQuadraticErrorCost(np.diag(v_cost), [0]*nv, v[:,n])

    # Make a new autodiff context for this constraint (to maximize cache hits)
    ad_velocity_dynamics_context = [ad_plant.CreateDefaultContext() for i in range(N)]
    def velocity_dynamics_constraint(vars, context_index):
        # constraint so that differences in current position and next position is correct velocity
        h, q, v, qn = np.split(vars, [1, 1+nq, 1+nq+nv])
        if isinstance(vars[0], AutoDiffXd):
            if not autoDiffArrayEqual(q, ad_plant.GetPositions(ad_velocity_dynamics_context[context_index])):
                ad_plant.SetPositions(ad_velocity_dynamics_context[context_index], q)
            v_from_qdot = ad_plant.MapQDotToVelocity(ad_velocity_dynamics_context[context_index], (qn - q)/h)
        else:
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            v_from_qdot = plant.MapQDotToVelocity(context[context_index], (qn - q)/h)
        return v - v_from_qdot
    for n in range(N-1):
        prog.AddConstraint(
            partial(velocity_dynamics_constraint, context_index=n),
            lb=[0]*nv, ub=[0]*nv,
            vars=np.concatenate(([h[n]], q[:,n], v[:,n], q[:,n+1])))

    # Contact forces
    contact_force = [prog.NewContinuousVariables(3, N-1, f"foot{foot}_contact_force") for foot in range(4)]
    ad_contact_force_context = [ad_plant.CreateDefaultContext() for i in range(N - 1)]
    def contact_force_constraint(vars, context_index):
        q, foot_force = np.split(vars, [nq])
        # Linear friction cone
        if isinstance(vars[0], AutoDiffXd):
            if not autoDiffArrayEqual(q, ad_plant.GetPositions(ad_contact_force_context[context_index])):
                ad_plant.SetPositions(ad_contact_force_context[context_index], q)
            rel_contact = ad_plant.GetBodyByName("ground").EvalPoseInWorld(ad_contact_force_context[context_index]).rotation().inverse().multiply(foot_force.reshape((-1, 1)))[:, 0]
        else:
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            rel_contact = plant.GetBodyByName("ground").EvalPoseInWorld(context[context_index]).rotation().inverse().multiply(foot_force.reshape((-1, 1)))[:, 0]
        return np.array([
            mu*rel_contact[2] - rel_contact[0],
            mu*rel_contact[2] + rel_contact[0],
            mu*rel_contact[2] - rel_contact[1],
            mu*rel_contact[2] + rel_contact[1],
        ])
    
    for n in range(N-1):
        for foot in range(4):
            prog.AddConstraint(
                partial(contact_force_constraint, context_index=n),
                lb=[0]*4, ub=[np.inf]*4,
                vars=np.concatenate((q[:,n], contact_force[foot][:,n])))
            prog.AddBoundingBoxConstraint(
                0, in_stance[foot, n] * 4 * 9.81 * total_mass,
                contact_force[foot][2, n])

    # set bridge initial condition (just set to be whatever it is in q0 from sethome)
    prog.AddLinearConstraint(q[0, 0]==q0[0])
    # TODO (ethan): add bridge force calculation from contact forces
    # TODO (ethan): enforce bridge rotaation due to gravity
    

    # Center of mass variables and constraints
    com = prog.NewContinuousVariables(3, N, "com")
    comdot = prog.NewContinuousVariables(3, N, "comdot")
    comddot = prog.NewContinuousVariables(3, N-1, "comddot")
    # Initial CoM x,y position == 0
    # TODO (ethan): change start position
    prog.AddBoundingBoxConstraint(0, 0, com[:2,0])
    # Initial CoM z vel == 0
    prog.AddBoundingBoxConstraint(0, 0, comdot[2,0])
    # CoM height
    # TODO (ethan): change height constraint
    prog.AddBoundingBoxConstraint(0.125, np.inf, com[2,:])
    # CoM x velocity >= 0
    prog.AddBoundingBoxConstraint(0, np.inf, comdot[0,:])
    # CoM final x position
    # TODO (ethan): change final position constraint
    if is_laterally_symmetric:
        prog.AddBoundingBoxConstraint(stride_length/2.0, stride_length/2.0, com[0,-1])
    else:
        prog.AddBoundingBoxConstraint(stride_length, stride_length, com[0,-1])
    # CoM dynamics
    for n in range(N-1):
        # Note: The original matlab implementation used backwards Euler (here and throughout),
        # which is a little more consistent with the LCP contact models.
        prog.AddConstraint(eq(com[:, n+1], com[:,n] + h[n]*comdot[:,n]))
        prog.AddConstraint(eq(comdot[:, n+1], comdot[:,n] + h[n]*comddot[:,n]))
        prog.AddConstraint(eq(total_mass*comddot[:,n], sum(contact_force[i][:,n] for i in range(4)) + total_mass*gravity))

    # Angular momentum (about the center of mass)
    H = prog.NewContinuousVariables(3, N, "H")
    Hdot = prog.NewContinuousVariables(3, N-1, "Hdot")
    prog.SetInitialGuess(H, np.zeros((3, N)))
    prog.SetInitialGuess(Hdot, np.zeros((3,N-1)))
    # Hdot = sum_i cross(p_FootiW-com, contact_force_i)
    def angular_momentum_constraint(vars, context_index):
        q, com, Hdot, contact_force = np.split(vars, [nq, nq+3, nq+6])
        contact_force = contact_force.reshape(3, 4, order='F')
        if isinstance(vars[0], AutoDiffXd):
            q = ExtractValue(q)
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            torque = np.zeros(3)
            for i in range(4):
                p_WF = plant.CalcPointsPositions(context[context_index], foot_frame[i], [0,0,0], plant.world_frame())
                Jq_WF = plant.CalcJacobianTranslationalVelocity(
                    context[context_index], JacobianWrtVariable.kQDot,
                    foot_frame[i], [0, 0, 0], plant.world_frame(), plant.world_frame())
                ad_p_WF = InitializeAutoDiff(p_WF, np.hstack((Jq_WF, np.zeros((3, 18)))))
                torque = torque + np.cross(ad_p_WF.reshape(3) - com, contact_force[:,i])
        else:
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            torque = np.zeros(3)
            for i in range(4):
                p_WF = plant.CalcPointsPositions(context[context_index], foot_frame[i], [0,0,0], plant.world_frame())
                torque += np.cross(p_WF.reshape(3) - com, contact_force[:,i])
        return Hdot - torque
    for n in range(N-1):
        prog.AddConstraint(eq(H[:,n+1], H[:,n] + h[n]*Hdot[:,n]))
        Fn = np.concatenate([contact_force[i][:,n] for i in range(4)])
        prog.AddConstraint(partial(angular_momentum_constraint, context_index=n), lb=np.zeros(3), ub=np.zeros(3),
                           vars=np.concatenate((q[:,n], com[:,n], Hdot[:,n], Fn)))
    
    BrVdot = prog.NewContinuousVariables(N-1, "BrVdot")
    def bridge_angular_momentum_constraint(vars, context_index):
        q, BrVdot, contact_force = np.split(vars, [nq, nq+1])
        contact_force = contact_force.reshape(3, 4, order='F')
        bridge_com = np.array([0, 0, 1]) # TODO (kenneth): don't hard-code the com of the bridge
        bridge_inertia = plant.GetBodyByName("ground").CalcSpatialInertiaInBodyFrame(plant_context).CalcRotationalInertia().CopyToFullMatrix3()
        if isinstance(vars[0], AutoDiffXd):
            q = ExtractValue(q)
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            torque_bridge = np.zeros(3)
            for i in range(4):
                p_WF = plant.CalcPointsPositions(context[context_index], foot_frame[i], [0,0,0], plant.world_frame())
                Jq_WF = plant.CalcJacobianTranslationalVelocity(
                    context[context_index], JacobianWrtVariable.kQDot,
                    foot_frame[i], [0, 0, 0], plant.world_frame(), plant.world_frame())
                ad_p_WF = InitializeAutoDiff(p_WF, np.hstack((Jq_WF, np.zeros((3, 18)))))
                torque_bridge = torque_bridge + np.cross(ad_p_WF.reshape(3) - bridge_com, contact_force[:,i])
        else:
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            torque_bridge = np.zeros(3)
            for i in range(4):
                p_WF = plant.CalcPointsPositions(context[context_index], foot_frame[i], [0,0,0], plant.world_frame())
                torque_bridge += np.cross(p_WF.reshape(3) - bridge_com, contact_force[:,i])
        # we use the Ixx entry in the inertia matrix, since the bridge spins along the x axis
        return bridge_inertia[0, 0] * BrVdot - torque_bridge.dot(np.array([1, 0, 0])) # TODO (kenneth): replace np array with bridge axis
    for n in range(N-1):
        prog.AddConstraint(v_view.rot1[n+1] == v_view.rot1[n] + h[n]*BrVdot[n])
        Fn = np.concatenate([contact_force[i][:,n] for i in range(4)])
        prog.AddConstraint(partial(bridge_angular_momentum_constraint, context_index=n), lb=np.zeros(1), ub=np.zeros(1),
                           vars=np.concatenate((q[:,n], [BrVdot[n]], Fn)))

    # com == CenterOfMass(q), H = SpatialMomentumInWorldAboutPoint(q, v, com)
    # Make a new autodiff context for this constraint (to maximize cache hits)
    com_constraint_context = [ad_plant.CreateDefaultContext() for i in range(N)]
    def com_constraint(vars, context_index):
        qv, com, H = np.split(vars, [nq+nv, nq+nv+3])
        if isinstance(vars[0], AutoDiffXd):
            if not autoDiffArrayEqual(qv, ad_plant.GetPositionsAndVelocities(com_constraint_context[context_index])):
                ad_plant.SetPositionsAndVelocities(com_constraint_context[context_index], qv)
            com_q = ad_plant.CalcCenterOfMassPositionInWorld(com_constraint_context[context_index], [littledog])
            H_qv = ad_plant.CalcSpatialMomentumInWorldAboutPoint(com_constraint_context[context_index], [littledog], com).rotational()
        else:
            if not np.array_equal(qv, plant.GetPositionsAndVelocities(context[context_index])):
                plant.SetPositionsAndVelocities(context[context_index], qv)
            com_q = plant.CalcCenterOfMassPositionInWorld(context[context_index], [littledog])
            H_qv = plant.CalcSpatialMomentumInWorldAboutPoint(context[context_index], [littledog], com).rotational()
        return np.concatenate((com_q - com, H_qv - H))
    for n in range(N):
        prog.AddConstraint(partial(com_constraint, context_index=n),
            lb=np.zeros(6), ub=np.zeros(6), vars=np.concatenate((q[:,n], v[:,n], com[:,n], H[:,n])))

    # TODO: Add collision constraints

    # Kinematic constraints
    def fixed_position_constraint(vars, context_index, frame):
        q, qn = np.split(vars, [nq])
        if not np.array_equal(q, plant.GetPositions(context[context_index])):
            plant.SetPositions(context[context_index], q)
        if not np.array_equal(qn, plant.GetPositions(context[context_index+1])):
            plant.SetPositions(context[context_index+1], qn)
        # TODO (ethan): might need to change this to be frame of bridge? idk
        p_WF = plant.CalcPointsPositions(context[context_index], frame, [0,0,0], plant.GetFrameByName("bridge_frame"))
        p_WF_n = plant.CalcPointsPositions(context[context_index+1], frame, [0,0,0], plant.GetFrameByName("bridge_frame"))
        if isinstance(vars[0], AutoDiffXd):
            J_WF = plant.CalcJacobianTranslationalVelocity(context[context_index], JacobianWrtVariable.kQDot,
                                                    frame, [0, 0, 0], plant.GetFrameByName("bridge_frame"), plant.GetFrameByName("bridge_frame"))
            J_WF_n = plant.CalcJacobianTranslationalVelocity(context[context_index+1], JacobianWrtVariable.kQDot,
                                                    frame, [0, 0, 0], plant.GetFrameByName("bridge_frame"), plant.GetFrameByName("bridge_frame"))
            return InitializeAutoDiff(
                p_WF_n - p_WF, J_WF_n @ ExtractGradient(qn) - J_WF @ ExtractGradient(q))
        else:
            return p_WF_n - p_WF
    for i in range(4):
        for n in range(N):
            if in_stance[i, n]:
                # foot should be on the ground (world position z=0)
                # TODO (ethan): change to height function (height from bridge == 0) - downward projection distance
                prog.AddConstraint(PositionConstraint(
                    plant, plant.GetFrameByName("bridge_frame"), [-np.inf,-np.inf,0.05], [np.inf,np.inf,0.05],
                    foot_frame[i], [0,0,0], context[n]), q[:,n])
                if n > 0 and in_stance[i, n-1]:
                    # feet should not move during stance.

                    #TODO (ethan): unsure if this needs to be modified
                    prog.AddConstraint(partial(fixed_position_constraint, context_index=n-1, frame=foot_frame[i]),
                                       lb=np.zeros(3), ub=np.zeros(3), vars=np.concatenate((q[:,n-1], q[:,n])))
            else:
                min_clearance = 0.01
                prog.AddConstraint(PositionConstraint(plant, plant.GetFrameByName("bridge_frame"), [-np.inf,-np.inf,0.05+min_clearance], [np.inf,np.inf,np.inf],foot_frame[i],[0,0,0],context[n]), q[:,n])
    
    # constraint foot relative position

    relative_foot_context = [ad_plant.CreateDefaultContext() for i in range(N)]
    def relative_foot_constraint(vars, context_index):
        q = vars
        if isinstance(vars[0], AutoDiffXd):
            if not autoDiffArrayEqual(q, ad_plant.GetPositions(relative_foot_context[context_index])):
                ad_plant.SetPositions(relative_foot_context[context_index], q)
            ys = []
            for name in ["front_left_foot_center", "front_right_foot_center", "back_left_foot_center", "back_right_foot_center"]:
                ys.append(ad_plant.GetFrameByName(name).CalcPoseInWorld(relative_foot_context[context_index]).translation()[1])
            return np.array([ys[0] - ys[1], ys[2] - ys[3]])
        else:
            if not np.array_equal(qv, plant.GetPositionsAndVelocities(context[context_index])):
                plant.SetPositions(context[context_index], q)
            ys = []
            for name in ["front_left_foot_center", "front_right_foot_center", "back_left_foot_center", "back_right_foot_center"]:
                ys.append(plant.GetFrameByName(name).CalcPoseInWorld(relative_foot_context[context_index]).translation()[1])
            return np.array([ys[0] - ys[1], ys[2] - ys[3]])
            
    
    for n in range(N):
        prog.AddConstraint(partial(relative_foot_constraint, context_index=n),
        lb=np.array([0.01, 0.01]), ub=np.array([np.inf, np.inf]), vars=q[:, n])
    
    # Periodicity constraints
    if is_laterally_symmetric:
        # Joints
        def AddAntiSymmetricPair(a, b):
            prog.AddLinearEqualityConstraint(a[0] == -b[-1])
            prog.AddLinearEqualityConstraint(a[-1] == -b[0])
        def AddSymmetricPair(a, b):
            prog.AddLinearEqualityConstraint(a[0] == b[-1])
            prog.AddLinearEqualityConstraint(a[-1] == b[0])

        AddAntiSymmetricPair(q_view.front_left_hip_roll,
                             q_view.front_right_hip_roll)
        AddSymmetricPair(q_view.front_left_hip_pitch,
                         q_view.front_right_hip_pitch)
        AddSymmetricPair(q_view.front_left_knee, q_view.front_right_knee)
        AddAntiSymmetricPair(q_view.back_left_hip_roll,
                             q_view.back_right_hip_roll)
        AddSymmetricPair(q_view.back_left_hip_pitch,
                         q_view.back_right_hip_pitch)
        AddSymmetricPair(q_view.back_left_knee, q_view.back_right_knee)
        prog.AddLinearEqualityConstraint(q_view.rot1[0] == -q_view.rot1[-1])
        prog.AddLinearEqualityConstraint(v_view.rot1[0] == -v_view.rot1[-1])
        prog.AddLinearEqualityConstraint(q_view.body_y[0] == -q_view.body_y[-1])
        prog.AddLinearEqualityConstraint(q_view.body_z[0] == q_view.body_z[-1])
        # Body orientation must be in the xz plane:
        prog.AddBoundingBoxConstraint(0, 0, q_view.body_qx[[0,-1]])
        prog.AddBoundingBoxConstraint(0, 0, q_view.body_qz[[0,-1]])

        # Floating base velocity
        prog.AddLinearEqualityConstraint(v_view.body_vx[0] == v_view.body_vx[-1])
        prog.AddLinearEqualityConstraint(v_view.body_vy[0] == -v_view.body_vy[-1])
        prog.AddLinearEqualityConstraint(v_view.body_vz[0] == v_view.body_vz[-1])

        # CoM velocity
        prog.AddLinearEqualityConstraint(comdot[0,0] == comdot[0,-1])
        prog.AddLinearEqualityConstraint(comdot[1,0] == -comdot[1,-1])
        prog.AddLinearEqualityConstraint(comdot[2,0] == comdot[2,-1])

    else:
        # Everything except body_x is periodic
        q_selector = PositionView([True]*nq)
        q_selector.body_x = False
        # make bridge periodic
        q_selector.rot1 = False
        prog.AddLinearConstraint(eq(q[q_selector,0], q[q_selector,-1]))
        prog.AddLinearConstraint(eq(v[:,0], v[:,-1]))

    # TODO: Set solver parameters (mostly to make the worst case solve times less bad)
    snopt = SnoptSolver().solver_id()
    if initial_guess is not None:
        prog.SetInitialGuessForAllVariables(initial_guess)
    prog.SetSolverOption(snopt, 'Iterations Limits', 1e5 if running_as_notebook else 1)
    prog.SetSolverOption(snopt, 'Major Iterations Limit', 200 if running_as_notebook else 1)
    prog.SetSolverOption(snopt, 'Major Feasibility Tolerance', 5e-6)
    prog.SetSolverOption(snopt, 'Major Optimality Tolerance', 1e-4)
    prog.SetSolverOption(snopt, 'Superbasics limit', 2000)
    prog.SetSolverOption(snopt, 'Linesearch tolerance', 0.9)
    #prog.SetSolverOption(snopt, 'Print file', 'snopt.out')

    # TODO a few more costs/constraints from
    # from https://github.com/RobotLocomotion/LittleDog/blob/master/gaitOptimization.m
    print("starting solver")
    result = Solve(prog)
    print(result.get_solver_id().name())
    print(result.is_success())  # We expect this to be false if iterations are limited.

    def HalfStrideToFullStride(a):
        b = PositionView(np.copy(a))

        b.body_y = -a.body_y
        # Mirror quaternion so that roll=-roll, yaw=-yaw
        b.body_qx = -a.body_qx
        b.body_qz = -a.body_qz

        b.front_left_hip_roll = -a.front_right_hip_roll
        b.front_right_hip_roll = -a.front_left_hip_roll
        b.back_left_hip_roll = -a.back_right_hip_roll
        b.back_right_hip_roll = -a.back_left_hip_roll

        b.front_left_hip_pitch = a.front_right_hip_pitch
        b.front_right_hip_pitch = a.front_left_hip_pitch
        b.back_left_hip_pitch = a.back_right_hip_pitch
        b.back_right_hip_pitch = a.back_left_hip_pitch

        b.front_left_knee = a.front_right_knee
        b.front_right_knee = a.front_left_knee
        b.back_left_knee = a.back_right_knee
        b.back_right_knee = a.back_left_knee

        b.rot1 = -a.rot1

        return b


    # Animate trajectory
    if final:
        context = diagram.CreateDefaultContext()
        plant_context = plant.GetMyContextFromRoot(context)
        t_sol = np.cumsum(np.concatenate(([0],result.GetSolution(h))))
        q_sol = PiecewisePolynomial.FirstOrderHold(t_sol, result.GetSolution(q))
        visualizer.StartRecording()
        num_strides = 4
        t0 = t_sol[0]
        tf = t_sol[-1]
        T = tf*num_strides*(2.0 if is_laterally_symmetric else 1.0)
        for t in np.hstack((np.arange(t0, T, 1.0/32.0), T)):
            context.SetTime(t)
            stride = (t - t0) // (tf - t0)
            ts = (t - t0) % (tf - t0)
            qt = PositionView(q_sol.value(ts))
            if is_laterally_symmetric:
                if stride % 2 == 1:
                    qt = HalfStrideToFullStride(qt)
                    qt.body_x += stride_length/2.0
                stride = stride // 2
            qt.body_x += stride*stride_length
            plant.SetPositions(plant_context, qt[:])
            diagram.Publish(context)

        visualizer.StopRecording()
        visualizer.PublishRecording()
    return result

# Try them all!  The last two could use a little tuning.
result = None

# result = gait_optimization('walking_trot', 0.01, result).GetSolution()
for i in range(10):
    result = gait_optimization('running_trot', i * 0.001, result, False).GetSolution()
result = gait_optimization('running_trot', 10 * 0.001, result, True).GetSolution()
# for i in range(2, 11):
#     result = gait_optimization('walking_trot', i * 0.01, result).GetSolution()
# gait_optimization('running_trot')
# gait_optimization('rotary_gallop')
# gait_optimization('bound')
# Out:
# [ 0.          0.00018405 -0.00953257]
# [[0.]
#  [0.]
#  [1.]]
# [[0.2 0.  0. ]
#  [0.  0.2 0. ]
#  [0.  0.  0.2]]
# q0 home positions: [ 0.     1.     0.     0.     0.     0.     0.     1.346  0.1    1.
#  -1.55  -0.1    1.    -1.55   0.1   -1.     1.55  -0.1   -1.     1.55 ]
# Entering MakeNamedViewPositions
# joint name front_left_hip_roll joint.num_positions 1
# joint name front_left_hip_pitch joint.num_positions 1
# joint name front_left_knee joint.num_positions 1
# joint name front_right_hip_roll joint.num_positions 1
# joint name front_right_hip_pitch joint.num_positions 1
# joint name front_right_knee joint.num_positions 1
# joint name back_left_hip_roll joint.num_positions 1
# joint name back_left_hip_pitch joint.num_positions 1
# joint name back_left_knee joint.num_positions 1
# joint name back_right_hip_roll joint.num_positions 1
# joint name back_right_hip_pitch joint.num_positions 1
# joint name back_right_knee joint.num_positions 1
# joint name rot1 joint.num_positions 1
# Exiting MakeNamedViewPositions
# ('rot1', 'body_qw', 'body_qx', 'body_qy', 'body_qz', 'body_x', 'body_y', 'body_z', 'front_left_hip_roll', 'front_left_hip_pitch', 'front_left_knee', 'front_right_hip_roll', 'front_right_hip_pitch', 'front_right_knee', 'back_left_hip_roll', 'back_left_hip_pitch', 'back_left_knee', 'back_right_hip_roll', 'back_right_hip_pitch', 'back_right_knee')
# starting solver
# SNOPT/fortran
# True
# [ 0.          0.00018405 -0.00953257]
# [[0.       ]
#  [0.001    ]
#  [0.9999995]]
# [[0.2 0.  0. ]
#  [0.  0.2 0. ]
#  [0.  0.  0.2]]
# q0 home positions: [ 1.000e-03  1.000e+00  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  1.346e+00  1.000e-01  1.000e+00 -1.550e+00 -1.000e-01
#   1.000e+00 -1.550e+00  1.000e-01 -1.000e+00  1.550e+00 -1.000e-01
#  -1.000e+00  1.550e+00]
# Entering MakeNamedViewPositions
# joint name front_left_hip_roll joint.num_positions 1
# joint name front_left_hip_pitch joint.num_positions 1
# joint name front_left_knee joint.num_positions 1
# joint name front_right_hip_roll joint.num_positions 1
# joint name front_right_hip_pitch joint.num_positions 1
# joint name front_right_knee joint.num_positions 1
# joint name back_left_hip_roll joint.num_positions 1
# joint name back_left_hip_pitch joint.num_positions 1
# joint name back_left_knee joint.num_positions 1
# joint name back_right_hip_roll joint.num_positions 1
# joint name back_right_hip_pitch joint.num_positions 1
# joint name back_right_knee joint.num_positions 1
# joint name rot1 joint.num_positions 1
# Exiting MakeNamedViewPositions
# ('rot1', 'body_qw', 'body_qx', 'body_qy', 'body_qz', 'body_x', 'body_y', 'body_z', 'front_left_hip_roll', 'front_left_hip_pitch', 'front_left_knee', 'front_right_hip_roll', 'front_right_hip_pitch', 'front_right_knee', 'back_left_hip_roll', 'back_left_hip_pitch', 'back_left_knee', 'back_right_hip_roll', 'back_right_hip_pitch', 'back_right_knee')
# starting solver
# SNOPT/fortran
# True
# [ 0.          0.00018405 -0.00953257]
# [[0.      ]
#  [0.002   ]
#  [0.999998]]
# [[0.2 0.  0. ]
#  [0.  0.2 0. ]
#  [0.  0.  0.2]]
# q0 home positions: [ 0.002  1.     0.     0.     0.     0.     0.     1.346  0.1    1.
#  -1.55  -0.1    1.    -1.55   0.1   -1.     1.55  -0.1   -1.     1.55 ]
# Entering MakeNamedViewPositions
# joint name front_left_hip_roll joint.num_positions 1
# joint name front_left_hip_pitch joint.num_positions 1
# joint name front_left_knee joint.num_positions 1
# joint name front_right_hip_roll joint.num_positions 1
# joint name front_right_hip_pitch joint.num_positions 1
# joint name front_right_knee joint.num_positions 1
# joint name back_left_hip_roll joint.num_positions 1
# joint name back_left_hip_pitch joint.num_positions 1
# joint name back_left_knee joint.num_positions 1
# joint name back_right_hip_roll joint.num_positions 1
# joint name back_right_hip_pitch joint.num_positions 1
# joint name back_right_knee joint.num_positions 1
# joint name rot1 joint.num_positions 1
# Exiting MakeNamedViewPositions
# ('rot1', 'body_qw', 'body_qx', 'body_qy', 'body_qz', 'body_x', 'body_y', 'body_z', 'front_left_hip_roll', 'front_left_hip_pitch', 'front_left_knee', 'front_right_hip_roll', 'front_right_hip_pitch', 'front_right_knee', 'back_left_hip_roll', 'back_left_hip_pitch', 'back_left_knee', 'back_right_hip_roll', 'back_right_hip_pitch', 'back_right_knee')
# starting solver
# SNOPT/fortran
# True
# [ 0.          0.00018405 -0.00953257]
# [[0.       ]
#  [0.003    ]
#  [0.9999955]]
# [[0.2 0.  0. ]
#  [0.  0.2 0. ]
#  [0.  0.  0.2]]
# q0 home positions: [ 0.003  1.     0.     0.     0.     0.     0.     1.346  0.1    1.
#  -1.55  -0.1    1.    -1.55   0.1   -1.     1.55  -0.1   -1.     1.55 ]
# Entering MakeNamedViewPositions
# joint name front_left_hip_roll joint.num_positions 1
# joint name front_left_hip_pitch joint.num_positions 1
# joint name front_left_knee joint.num_positions 1
# joint name front_right_hip_roll joint.num_positions 1
# joint name front_right_hip_pitch joint.num_positions 1
# joint name front_right_knee joint.num_positions 1
# joint name back_left_hip_roll joint.num_positions 1
# joint name back_left_hip_pitch joint.num_positions 1
# joint name back_left_knee joint.num_positions 1
# joint name back_right_hip_roll joint.num_positions 1
# joint name back_right_hip_pitch joint.num_positions 1
# joint name back_right_knee joint.num_positions 1
# joint name rot1 joint.num_positions 1
# Exiting MakeNamedViewPositions
# ('rot1', 'body_qw', 'body_qx', 'body_qy', 'body_qz', 'body_x', 'body_y', 'body_z', 'front_left_hip_roll', 'front_left_hip_pitch', 'front_left_knee', 'front_right_hip_roll', 'front_right_hip_pitch', 'front_right_knee', 'back_left_hip_roll', 'back_left_hip_pitch', 'back_left_knee', 'back_right_hip_roll', 'back_right_hip_pitch', 'back_right_knee')
# starting solver
# SNOPT/fortran
# True
# [ 0.          0.00018405 -0.00953257]
# [[0.        ]
#  [0.00399999]
#  [0.999992  ]]
# [[0.2 0.  0. ]
#  [0.  0.2 0. ]
#  [0.  0.  0.2]]
# q0 home positions: [ 0.004  1.     0.     0.     0.     0.     0.     1.346  0.1    1.
#  -1.55  -0.1    1.    -1.55   0.1   -1.     1.55  -0.1   -1.     1.55 ]
# Entering MakeNamedViewPositions
# joint name front_left_hip_roll joint.num_positions 1
# joint name front_left_hip_pitch joint.num_positions 1
# joint name front_left_knee joint.num_positions 1
# joint name front_right_hip_roll joint.num_positions 1
# joint name front_right_hip_pitch joint.num_positions 1
# joint name front_right_knee joint.num_positions 1
# joint name back_left_hip_roll joint.num_positions 1
# joint name back_left_hip_pitch joint.num_positions 1
# joint name back_left_knee joint.num_positions 1
# joint name back_right_hip_roll joint.num_positions 1
# joint name back_right_hip_pitch joint.num_positions 1
# joint name back_right_knee joint.num_positions 1
# joint name rot1 joint.num_positions 1
# Exiting MakeNamedViewPositions
# ('rot1', 'body_qw', 'body_qx', 'body_qy', 'body_qz', 'body_x', 'body_y', 'body_z', 'front_left_hip_roll', 'front_left_hip_pitch', 'front_left_knee', 'front_right_hip_roll', 'front_right_hip_pitch', 'front_right_knee', 'back_left_hip_roll', 'back_left_hip_pitch', 'back_left_knee', 'back_right_hip_roll', 'back_right_hip_pitch', 'back_right_knee')
# starting solver
# SNOPT/fortran
# True
# [ 0.          0.00018405 -0.00953257]
# [[0.        ]
#  [0.00499998]
#  [0.9999875 ]]
# [[0.2 0.  0. ]
#  [0.  0.2 0. ]
#  [0.  0.  0.2]]
# q0 home positions: [ 0.005  1.     0.     0.     0.     0.     0.     1.346  0.1    1.
#  -1.55  -0.1    1.    -1.55   0.1   -1.     1.55  -0.1   -1.     1.55 ]
# Entering MakeNamedViewPositions
# joint name front_left_hip_roll joint.num_positions 1
# joint name front_left_hip_pitch joint.num_positions 1
# joint name front_left_knee joint.num_positions 1
# joint name front_right_hip_roll joint.num_positions 1
# joint name front_right_hip_pitch joint.num_positions 1
# joint name front_right_knee joint.num_positions 1
# joint name back_left_hip_roll joint.num_positions 1
# joint name back_left_hip_pitch joint.num_positions 1
# joint name back_left_knee joint.num_positions 1
# joint name back_right_hip_roll joint.num_positions 1
# joint name back_right_hip_pitch joint.num_positions 1
# joint name back_right_knee joint.num_positions 1
# joint name rot1 joint.num_positions 1
# Exiting MakeNamedViewPositions
# ('rot1', 'body_qw', 'body_qx', 'body_qy', 'body_qz', 'body_x', 'body_y', 'body_z', 'front_left_hip_roll', 'front_left_hip_pitch', 'front_left_knee', 'front_right_hip_roll', 'front_right_hip_pitch', 'front_right_knee', 'back_left_hip_roll', 'back_left_hip_pitch', 'back_left_knee', 'back_right_hip_roll', 'back_right_hip_pitch', 'back_right_knee')
# starting solver
# SNOPT/fortran
# False
# [ 0.          0.00018405 -0.00953257]
# [[0.        ]
#  [0.00599996]
#  [0.999982  ]]
# [[0.2 0.  0. ]
#  [0.  0.2 0. ]
#  [0.  0.  0.2]]
# q0 home positions: [ 0.006  1.     0.     0.     0.     0.     0.     1.346  0.1    1.
#  -1.55  -0.1    1.    -1.55   0.1   -1.     1.55  -0.1   -1.     1.55 ]
# Entering MakeNamedViewPositions
# joint name front_left_hip_roll joint.num_positions 1
# joint name front_left_hip_pitch joint.num_positions 1
# joint name front_left_knee joint.num_positions 1
# joint name front_right_hip_roll joint.num_positions 1
# joint name front_right_hip_pitch joint.num_positions 1
# joint name front_right_knee joint.num_positions 1
# joint name back_left_hip_roll joint.num_positions 1
# joint name back_left_hip_pitch joint.num_positions 1
# joint name back_left_knee joint.num_positions 1
# joint name back_right_hip_roll joint.num_positions 1
# joint name back_right_hip_pitch joint.num_positions 1
# joint name back_right_knee joint.num_positions 1
# joint name rot1 joint.num_positions 1
# Exiting MakeNamedViewPositions
# ('rot1', 'body_qw', 'body_qx', 'body_qy', 'body_qz', 'body_x', 'body_y', 'body_z', 'front_left_hip_roll', 'front_left_hip_pitch', 'front_left_knee', 'front_right_hip_roll', 'front_right_hip_pitch', 'front_right_knee', 'back_left_hip_roll', 'back_left_hip_pitch', 'back_left_knee', 'back_right_hip_roll', 'back_right_hip_pitch', 'back_right_knee')
# starting solver
# SNOPT/fortran
# True
# [ 0.          0.00018405 -0.00953257]
# [[0.        ]
#  [0.00699994]
#  [0.9999755 ]]
# [[0.2 0.  0. ]
#  [0.  0.2 0. ]
#  [0.  0.  0.2]]
# q0 home positions: [ 0.007  1.     0.     0.     0.     0.     0.     1.346  0.1    1.
#  -1.55  -0.1    1.    -1.55   0.1   -1.     1.55  -0.1   -1.     1.55 ]
# Entering MakeNamedViewPositions
# joint name front_left_hip_roll joint.num_positions 1
# joint name front_left_hip_pitch joint.num_positions 1
# joint name front_left_knee joint.num_positions 1
# joint name front_right_hip_roll joint.num_positions 1
# joint name front_right_hip_pitch joint.num_positions 1
# joint name front_right_knee joint.num_positions 1
# joint name back_left_hip_roll joint.num_positions 1
# joint name back_left_hip_pitch joint.num_positions 1
# joint name back_left_knee joint.num_positions 1
# joint name back_right_hip_roll joint.num_positions 1
# joint name back_right_hip_pitch joint.num_positions 1
# joint name back_right_knee joint.num_positions 1
# joint name rot1 joint.num_positions 1
# Exiting MakeNamedViewPositions
# ('rot1', 'body_qw', 'body_qx', 'body_qy', 'body_qz', 'body_x', 'body_y', 'body_z', 'front_left_hip_roll', 'front_left_hip_pitch', 'front_left_knee', 'front_right_hip_roll', 'front_right_hip_pitch', 'front_right_knee', 'back_left_hip_roll', 'back_left_hip_pitch', 'back_left_knee', 'back_right_hip_roll', 'back_right_hip_pitch', 'back_right_knee')
# starting solver
# SNOPT/fortran
# True
# [ 0.          0.00018405 -0.00953257]
# [[0.        ]
#  [0.00799991]
#  [0.999968  ]]
# [[0.2 0.  0. ]
#  [0.  0.2 0. ]
#  [0.  0.  0.2]]
# q0 home positions: [ 0.008  1.     0.     0.     0.     0.     0.     1.346  0.1    1.
#  -1.55  -0.1    1.    -1.55   0.1   -1.     1.55  -0.1   -1.     1.55 ]
# Entering MakeNamedViewPositions
# joint name front_left_hip_roll joint.num_positions 1
# joint name front_left_hip_pitch joint.num_positions 1
# joint name front_left_knee joint.num_positions 1
# joint name front_right_hip_roll joint.num_positions 1
# joint name front_right_hip_pitch joint.num_positions 1
# joint name front_right_knee joint.num_positions 1
# joint name back_left_hip_roll joint.num_positions 1
# joint name back_left_hip_pitch joint.num_positions 1
# joint name back_left_knee joint.num_positions 1
# joint name back_right_hip_roll joint.num_positions 1
# joint name back_right_hip_pitch joint.num_positions 1
# joint name back_right_knee joint.num_positions 1
# joint name rot1 joint.num_positions 1
# Exiting MakeNamedViewPositions
# ('rot1', 'body_qw', 'body_qx', 'body_qy', 'body_qz', 'body_x', 'body_y', 'body_z', 'front_left_hip_roll', 'front_left_hip_pitch', 'front_left_knee', 'front_right_hip_roll', 'front_right_hip_pitch', 'front_right_knee', 'back_left_hip_roll', 'back_left_hip_pitch', 'back_left_knee', 'back_right_hip_roll', 'back_right_hip_pitch', 'back_right_knee')
# starting solver
# SNOPT/fortran
# True
# [ 0.          0.00018405 -0.00953257]
# [[0.        ]
#  [0.00899988]
#  [0.9999595 ]]
# [[0.2 0.  0. ]
#  [0.  0.2 0. ]
#  [0.  0.  0.2]]
# q0 home positions: [ 0.009  1.     0.     0.     0.     0.     0.     1.346  0.1    1.
#  -1.55  -0.1    1.    -1.55   0.1   -1.     1.55  -0.1   -1.     1.55 ]
# Entering MakeNamedViewPositions
# joint name front_left_hip_roll joint.num_positions 1
# joint name front_left_hip_pitch joint.num_positions 1
# joint name front_left_knee joint.num_positions 1
# joint name front_right_hip_roll joint.num_positions 1
# joint name front_right_hip_pitch joint.num_positions 1
# joint name front_right_knee joint.num_positions 1
# joint name back_left_hip_roll joint.num_positions 1
# joint name back_left_hip_pitch joint.num_positions 1
# joint name back_left_knee joint.num_positions 1
# joint name back_right_hip_roll joint.num_positions 1
# joint name back_right_hip_pitch joint.num_positions 1
# joint name back_right_knee joint.num_positions 1
# joint name rot1 joint.num_positions 1
# Exiting MakeNamedViewPositions
# ('rot1', 'body_qw', 'body_qx', 'body_qy', 'body_qz', 'body_x', 'body_y', 'body_z', 'front_left_hip_roll', 'front_left_hip_pitch', 'front_left_knee', 'front_right_hip_roll', 'front_right_hip_pitch', 'front_right_knee', 'back_left_hip_roll', 'back_left_hip_pitch', 'back_left_knee', 'back_right_hip_roll', 'back_right_hip_pitch', 'back_right_knee')
# starting solver
# SNOPT/fortran
# True
# [ 0.          0.00018405 -0.00953257]
# [[0.        ]
#  [0.00999983]
#  [0.99995   ]]
# [[0.2 0.  0. ]
#  [0.  0.2 0. ]
#  [0.  0.  0.2]]
# q0 home positions: [ 0.01   1.     0.     0.     0.     0.     0.     1.346  0.1    1.
#  -1.55  -0.1    1.    -1.55   0.1   -1.     1.55  -0.1   -1.     1.55 ]
# Entering MakeNamedViewPositions
# joint name front_left_hip_roll joint.num_positions 1
# joint name front_left_hip_pitch joint.num_positions 1
# joint name front_left_knee joint.num_positions 1
# joint name front_right_hip_roll joint.num_positions 1
# joint name front_right_hip_pitch joint.num_positions 1
# joint name front_right_knee joint.num_positions 1
# joint name back_left_hip_roll joint.num_positions 1
# joint name back_left_hip_pitch joint.num_positions 1
# joint name back_left_knee joint.num_positions 1
# joint name back_right_hip_roll joint.num_positions 1
# joint name back_right_hip_pitch joint.num_positions 1
# joint name back_right_knee joint.num_positions 1
# joint name rot1 joint.num_positions 1
# Exiting MakeNamedViewPositions
# ('rot1', 'body_qw', 'body_qx', 'body_qy', 'body_qz', 'body_x', 'body_y', 'body_z', 'front_left_hip_roll', 'front_left_hip_pitch', 'front_left_knee', 'front_right_hip_roll', 'front_right_hip_pitch', 'front_right_knee', 'back_left_hip_roll', 'back_left_hip_pitch', 'back_left_knee', 'back_right_hip_roll', 'back_right_hip_pitch', 'back_right_knee')
# starting solver
# SNOPT/fortran
# True

# %% [markdown]
# use thing for initial guess

# %%
# TODO (kenneth): allow kinetic friction, stop relying on pre-specified mode sequence

def set_home(plant, context, ground_angle):
    # used in traj optimization for setting initial quess positions
    hip_roll = .1;
    hip_pitch = 1;
    knee = 1.55;
    plant.GetJointByName("front_right_hip_roll").set_angle(context, -hip_roll)
    plant.GetJointByName("front_right_hip_pitch").set_angle(context, hip_pitch)
    plant.GetJointByName("front_right_knee").set_angle(context, -knee)
    plant.GetJointByName("front_left_hip_roll").set_angle(context, hip_roll)
    plant.GetJointByName("front_left_hip_pitch").set_angle(context, hip_pitch)
    plant.GetJointByName("front_left_knee").set_angle(context, -knee)
    plant.GetJointByName("back_right_hip_roll").set_angle(context, -hip_roll)
    plant.GetJointByName("back_right_hip_pitch").set_angle(context, -hip_pitch)
    plant.GetJointByName("back_right_knee").set_angle(context, knee)
    plant.GetJointByName("back_left_hip_roll").set_angle(context, hip_roll)
    plant.GetJointByName("back_left_hip_pitch").set_angle(context, -hip_pitch)
    plant.GetJointByName("back_left_knee").set_angle(context, knee)
    plant.SetFreeBodyPose(context, plant.GetBodyByName("body"), RigidTransform([0, 0, 1.346]))
    # plant.SetFreeBodyPose(context, plant.GetBodyByName("body"), RigidTransform([0, 0, 0.146]))
    plant.GetJointByName("rot1").set_angle(context, ground_angle)

# Need this because a==b returns True even if a = AutoDiffXd(1, [1, 2]), b= AutoDiffXd(2, [3, 4])
# That's the behavior of AutoDiffXd in C++, also.
def autoDiffArrayEqual(a,b):
    return np.array_equal(a, b) and np.array_equal(ExtractGradient(a), ExtractGradient(b))

# TODO: promote this to drake (and make a version with model_instance)
def MakeNamedViewPositions(mbp, view_name):
    names = [None]*mbp.num_positions()
    print("Entering MakeNamedViewPositions")
    for ind in range(mbp.num_joints()):
        joint = mbp.get_joint(JointIndex(ind))
        if joint.num_positions() == 0:
            # skip weld joints
            continue
        print('joint name', joint.name(), 'joint.num_positions', joint.num_positions())
        # TODO: Handle planar joints, etc.
        # assert(joint.num_positions() == 1)
        names[joint.position_start()] = joint.name()
    
    for ind in mbp.GetFloatingBaseBodies():
        body = mbp.get_body(ind)
        start = body.floating_positions_start()
        body_name = body.name()
        names[start] = body_name+'_qw'
        names[start+1] = body_name+'_qx'
        names[start+2] = body_name+'_qy'
        names[start+3] = body_name+'_qz'
        names[start+4] = body_name+'_x'
        names[start+5] = body_name+'_y'
        names[start+6] = body_name+'_z'
    print("Exiting MakeNamedViewPositions")
    return namedview(view_name, names)

def MakeNamedViewVelocities(mbp, view_name):
    names = [None]*mbp.num_velocities()
    for ind in range(mbp.num_joints()):
        joint = mbp.get_joint(JointIndex(ind))
        if joint.num_positions() == 0:
            # skip weld joints
            continue
        # print('joint name', joint.name(), 'joint.num_positions', joint.num_positions())
        # TODO: Handle planar joints, etc.
        # assert(joint.num_velocities() == 1)
        names[joint.velocity_start()] = joint.name()
    for ind in mbp.GetFloatingBaseBodies():
        body = mbp.get_body(ind)
        start = body.floating_velocities_start() - mbp.num_positions()
        body_name = body.name()
        names[start] = body_name+'_wx'
        names[start+1] = body_name+'_wy'
        names[start+2] = body_name+'_wz'
        names[start+3] = body_name+'_vx'
        names[start+4] = body_name+'_vy'
        names[start+5] = body_name+'_vz'
    return namedview(view_name, names)

def gait_optimization(gait = 'walking_trot', ground_angle=0, initial_guess=None):
    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, 1e-3)
    parser = Parser(plant)
    littledog = parser.AddModelFromFile(FindResource('models/littledog/LittleDog.urdf'))
    bridge = parser.AddModelFromFile('./ground.urdf')
    plant.Finalize()
    visualizer = MeshcatVisualizerCpp.AddToBuilder(builder, scene_graph,
                                                   meshcat)

    diagram = builder.Build()
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyContextFromRoot(context)
    set_home(plant, plant_context, ground_angle)
    diagram.Publish(context)
    print(plant.CalcCenterOfMassPositionInWorld(plant.CreateDefaultContext(), [littledog]))
    print(plant.GetBodyByName("ground").EvalPoseInWorld(plant_context).rotation().inverse().multiply(np.array([[0.0, 0.0, 1.0]]).T))
    print(np.linalg.inv(plant.GetBodyByName("ground").CalcSpatialInertiaInBodyFrame(plant_context).CalcRotationalInertia().CopyToFullMatrix3()))
    # raise RuntimeError()

    q0 = plant.GetPositions(plant_context)
    print('q0 home positions:', q0)
    body_frame = plant.GetFrameByName("body")

    PositionView = MakeNamedViewPositions(plant, "Positions")
    VelocityView = MakeNamedViewVelocities(plant, "Velocities")

    mu = 1 # rubber on rubber
    total_mass = sum(plant.get_body(index).get_mass(context) for index in plant.GetBodyIndices(littledog))
    gravity = plant.gravity_field().gravity_vector()

    nq = 12
    foot_frame = [
        plant.GetFrameByName('front_left_foot_center'),
        plant.GetFrameByName('front_right_foot_center'),
        plant.GetFrameByName('back_left_foot_center'),
        plant.GetFrameByName('back_right_foot_center')]

    # setup gait
    is_laterally_symmetric = False
    check_self_collision = False
    if gait == 'running_trot':
        N = 21
        in_stance = np.zeros((4, N))
        in_stance[1, 3:17] = 1
        in_stance[2, 3:17] = 1
        speed = 0.9
        stride_length = .55
        is_laterally_symmetric = True
    elif gait == 'walking_trot':
        N = 21
        in_stance = np.zeros((4, N))
        in_stance[0, :11] = 1
        in_stance[1, 8:N] = 1
        in_stance[2, 8:N] = 1
        in_stance[3, :11] = 1
        speed = 0.4
        stride_length = .25
        is_laterally_symmetric = True
    elif gait == 'rotary_gallop':
        N = 41
        in_stance = np.zeros((4, N))
        in_stance[0, 7:19] = 1
        in_stance[1, 3:15] = 1
        in_stance[2, 24:35] = 1
        in_stance[3, 26:38] = 1
        speed = 1
        stride_length = .65
        check_self_collision = True
    elif gait == 'bound':
        N = 41
        in_stance = np.zeros((4, N))
        in_stance[0, 6:18] = 1
        in_stance[1, 6:18] = 1
        in_stance[2, 21:32] = 1
        in_stance[3, 21:32] = 1
        speed = 1.2
        stride_length = .55
        check_self_collision = True
    else:
        raise RuntimeError('Unknown gait.')


    T = stride_length / speed
    if is_laterally_symmetric:
        T = T / 2.0

    prog = MathematicalProgram()

    # Time steps
    h = prog.NewContinuousVariables(N-1, "h")
    prog.AddBoundingBoxConstraint(0.5*T/N, 2.0*T/N, h)
    prog.AddLinearConstraint(sum(h) >= .9*T)
    prog.AddLinearConstraint(sum(h) <= 1.1*T)

    # Create one context per timestep (to maximize cache hits)
    context = [plant.CreateDefaultContext() for i in range(N)]
    # We could get rid of this by implementing a few more Jacobians in MultibodyPlant:
    ad_plant = plant.ToAutoDiffXd()

    # Joint positions and velocities

    # 20 positions - 19 for the dog, 1 for the bridge joint (note that the bridge joint is index 0)
    nq = plant.num_positions()
    # 19 velocities (not sure why there's one less)
    nv = plant.num_velocities()
    q = prog.NewContinuousVariables(nq, N, "q")
    v = prog.NewContinuousVariables(nv, N, "v")

    # for n in range(N):
        
    #     prog.AddLinearConstraint(q[0, n] == 0)
    #     prog.AddLinearConstraint(v[0, n] == 0)

    q_view = PositionView(q)
    print(q_view.get_fields())
    v_view = VelocityView(v)
    q0_view = PositionView(q0)
    # Joint costs
    q_cost = PositionView([1]*nq)
    v_cost = VelocityView([1]*nv)
    q_cost.body_x = 0
    q_cost.body_y = 0
    q_cost.body_qx = 0
    q_cost.body_qy = 0
    q_cost.body_qz = 0
    q_cost.body_qw = 0
    q_cost.front_left_hip_roll = 5
    q_cost.front_right_hip_roll = 5
    q_cost.back_left_hip_roll = 5
    q_cost.back_right_hip_roll = 5
    v_cost.body_vx = 0
    v_cost.body_wx = 0
    v_cost.body_wy = 0
    v_cost.body_wz = 0

    for n in range(N):
        # Joint limits
        # limits are -inf and inf for ind 0 (bridge joint)
        prog.AddBoundingBoxConstraint(plant.GetPositionLowerLimits()[8:], plant.GetPositionUpperLimits()[8:], q[8:,n])
        # Joint velocity limits
        prog.AddBoundingBoxConstraint(plant.GetVelocityLowerLimits()[8:], plant.GetVelocityUpperLimits()[8:], v[8:,n])
        # Unit quaternions
        AddUnitQuaternionConstraintOnPlant(plant, q[:,n], prog)
        # Body orientation
        # prog.AddConstraint(OrientationConstraint(plant,
        #                                          body_frame, RotationMatrix(),
        #                                          plant.world_frame(), RotationMatrix(),
        #                                          0.1, context[n]), q[:,n])
        # Initial guess for all joint angles is the home position
        prog.SetInitialGuess(q[:,n], q0)  # Solvers get stuck if the quaternion is initialized with all zeros.

        # Running costs:
        prog.AddQuadraticErrorCost(np.diag(q_cost), q0, q[:,n])
        prog.AddQuadraticErrorCost(np.diag(v_cost), [0]*nv, v[:,n])

    # Make a new autodiff context for this constraint (to maximize cache hits)
    ad_velocity_dynamics_context = [ad_plant.CreateDefaultContext() for i in range(N)]
    def velocity_dynamics_constraint(vars, context_index):
        # constraint so that differences in current position and next position is correct velocity
        h, q, v, qn = np.split(vars, [1, 1+nq, 1+nq+nv])
        if isinstance(vars[0], AutoDiffXd):
            if not autoDiffArrayEqual(q, ad_plant.GetPositions(ad_velocity_dynamics_context[context_index])):
                ad_plant.SetPositions(ad_velocity_dynamics_context[context_index], q)
            v_from_qdot = ad_plant.MapQDotToVelocity(ad_velocity_dynamics_context[context_index], (qn - q)/h)
        else:
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            v_from_qdot = plant.MapQDotToVelocity(context[context_index], (qn - q)/h)
        return v - v_from_qdot
    for n in range(N-1):
        prog.AddConstraint(
            partial(velocity_dynamics_constraint, context_index=n),
            lb=[0]*nv, ub=[0]*nv,
            vars=np.concatenate(([h[n]], q[:,n], v[:,n], q[:,n+1])))

    # Contact forces
    contact_force = [prog.NewContinuousVariables(3, N-1, f"foot{foot}_contact_force") for foot in range(4)]
    ad_contact_force_context = [ad_plant.CreateDefaultContext() for i in range(N - 1)]
    def contact_force_constraint(vars, context_index):
        q, foot_force = np.split(vars, [nq])
        # Linear friction cone
        if isinstance(vars[0], AutoDiffXd):
            if not autoDiffArrayEqual(q, ad_plant.GetPositions(ad_contact_force_context[context_index])):
                ad_plant.SetPositions(ad_contact_force_context[context_index], q)
            rel_contact = ad_plant.GetBodyByName("ground").EvalPoseInWorld(ad_contact_force_context[context_index]).rotation().inverse().multiply(foot_force.reshape((-1, 1)))[:, 0]
        else:
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            rel_contact = plant.GetBodyByName("ground").EvalPoseInWorld(context[context_index]).rotation().inverse().multiply(foot_force.reshape((-1, 1)))[:, 0]
        return np.array([
            mu*rel_contact[2] - rel_contact[0],
            mu*rel_contact[2] + rel_contact[0],
            mu*rel_contact[2] - rel_contact[1],
            mu*rel_contact[2] + rel_contact[1],
        ])
    
    for n in range(N-1):
        for foot in range(4):
            prog.AddConstraint(
                partial(contact_force_constraint, context_index=n),
                lb=[0]*4, ub=[np.inf]*4,
                vars=np.concatenate((q[:,n], contact_force[foot][:,n])))
            prog.AddBoundingBoxConstraint(
                0, in_stance[foot, n] * 4 * 9.81 * total_mass,
                contact_force[foot][2, n])

    # set bridge initial condition (just set to be whatever it is in q0 from sethome)
    prog.AddLinearConstraint(q[0, 0]==q0[0])
    # TODO (ethan): add bridge force calculation from contact forces
    # TODO (ethan): enforce bridge rotaation due to gravity
    

    # Center of mass variables and constraints
    com = prog.NewContinuousVariables(3, N, "com")
    comdot = prog.NewContinuousVariables(3, N, "comdot")
    comddot = prog.NewContinuousVariables(3, N-1, "comddot")
    # Initial CoM x,y position == 0
    # TODO (ethan): change start position
    prog.AddBoundingBoxConstraint(0, 0, com[:2,0])
    # Initial CoM z vel == 0
    prog.AddBoundingBoxConstraint(0, 0, comdot[2,0])
    # CoM height
    # TODO (ethan): change height constraint
    prog.AddBoundingBoxConstraint(0.125, np.inf, com[2,:])
    # CoM x velocity >= 0
    prog.AddBoundingBoxConstraint(0, np.inf, comdot[0,:])
    # CoM final x position
    # TODO (ethan): change final position constraint
    if is_laterally_symmetric:
        prog.AddBoundingBoxConstraint(stride_length/2.0, stride_length/2.0, com[0,-1])
    else:
        prog.AddBoundingBoxConstraint(stride_length, stride_length, com[0,-1])
    # CoM dynamics
    for n in range(N-1):
        # Note: The original matlab implementation used backwards Euler (here and throughout),
        # which is a little more consistent with the LCP contact models.
        prog.AddConstraint(eq(com[:, n+1], com[:,n] + h[n]*comdot[:,n]))
        prog.AddConstraint(eq(comdot[:, n+1], comdot[:,n] + h[n]*comddot[:,n]))
        prog.AddConstraint(eq(total_mass*comddot[:,n], sum(contact_force[i][:,n] for i in range(4)) + total_mass*gravity))

    # Angular momentum (about the center of mass)
    H = prog.NewContinuousVariables(3, N, "H")
    Hdot = prog.NewContinuousVariables(3, N-1, "Hdot")
    prog.SetInitialGuess(H, np.zeros((3, N)))
    prog.SetInitialGuess(Hdot, np.zeros((3,N-1)))
    # Hdot = sum_i cross(p_FootiW-com, contact_force_i)
    def angular_momentum_constraint(vars, context_index):
        q, com, Hdot, contact_force = np.split(vars, [nq, nq+3, nq+6])
        contact_force = contact_force.reshape(3, 4, order='F')
        if isinstance(vars[0], AutoDiffXd):
            q = ExtractValue(q)
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            torque = np.zeros(3)
            for i in range(4):
                p_WF = plant.CalcPointsPositions(context[context_index], foot_frame[i], [0,0,0], plant.world_frame())
                Jq_WF = plant.CalcJacobianTranslationalVelocity(
                    context[context_index], JacobianWrtVariable.kQDot,
                    foot_frame[i], [0, 0, 0], plant.world_frame(), plant.world_frame())
                ad_p_WF = InitializeAutoDiff(p_WF, np.hstack((Jq_WF, np.zeros((3, 18)))))
                torque = torque + np.cross(ad_p_WF.reshape(3) - com, contact_force[:,i])
        else:
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            torque = np.zeros(3)
            for i in range(4):
                p_WF = plant.CalcPointsPositions(context[context_index], foot_frame[i], [0,0,0], plant.world_frame())
                torque += np.cross(p_WF.reshape(3) - com, contact_force[:,i])
        return Hdot - torque
    for n in range(N-1):
        prog.AddConstraint(eq(H[:,n+1], H[:,n] + h[n]*Hdot[:,n]))
        Fn = np.concatenate([contact_force[i][:,n] for i in range(4)])
        prog.AddConstraint(partial(angular_momentum_constraint, context_index=n), lb=np.zeros(3), ub=np.zeros(3),
                           vars=np.concatenate((q[:,n], com[:,n], Hdot[:,n], Fn)))
    
    BrVdot = prog.NewContinuousVariables(N-1, "BrVdot")
    def bridge_angular_momentum_constraint(vars, context_index):
        q, BrVdot, contact_force = np.split(vars, [nq, nq+1])
        contact_force = contact_force.reshape(3, 4, order='F')
        bridge_com = np.array([0, 0, 1]) # TODO (kenneth): don't hard-code the com of the bridge
        bridge_inertia = plant.GetBodyByName("ground").CalcSpatialInertiaInBodyFrame(plant_context).CalcRotationalInertia().CopyToFullMatrix3()
        if isinstance(vars[0], AutoDiffXd):
            q = ExtractValue(q)
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            torque_bridge = np.zeros(3)
            for i in range(4):
                p_WF = plant.CalcPointsPositions(context[context_index], foot_frame[i], [0,0,0], plant.world_frame())
                Jq_WF = plant.CalcJacobianTranslationalVelocity(
                    context[context_index], JacobianWrtVariable.kQDot,
                    foot_frame[i], [0, 0, 0], plant.world_frame(), plant.world_frame())
                ad_p_WF = InitializeAutoDiff(p_WF, np.hstack((Jq_WF, np.zeros((3, 18)))))
                torque_bridge = torque_bridge + np.cross(ad_p_WF.reshape(3) - bridge_com, contact_force[:,i])
        else:
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            torque_bridge = np.zeros(3)
            for i in range(4):
                p_WF = plant.CalcPointsPositions(context[context_index], foot_frame[i], [0,0,0], plant.world_frame())
                torque_bridge += np.cross(p_WF.reshape(3) - bridge_com, contact_force[:,i])
        # we use the Ixx entry in the inertia matrix, since the bridge spins along the x axis
        return bridge_inertia[0, 0] * BrVdot - torque_bridge.dot(np.array([1, 0, 0])) # TODO (kenneth): replace np array with bridge axis
    for n in range(N-1):
        prog.AddConstraint(v_view.rot1[n+1] == v_view.rot1[n] + h[n]*BrVdot[n])
        Fn = np.concatenate([contact_force[i][:,n] for i in range(4)])
        prog.AddConstraint(partial(bridge_angular_momentum_constraint, context_index=n), lb=np.zeros(1), ub=np.zeros(1),
                           vars=np.concatenate((q[:,n], [BrVdot[n]], Fn)))

    # com == CenterOfMass(q), H = SpatialMomentumInWorldAboutPoint(q, v, com)
    # Make a new autodiff context for this constraint (to maximize cache hits)
    com_constraint_context = [ad_plant.CreateDefaultContext() for i in range(N)]
    def com_constraint(vars, context_index):
        qv, com, H = np.split(vars, [nq+nv, nq+nv+3])
        if isinstance(vars[0], AutoDiffXd):
            if not autoDiffArrayEqual(qv, ad_plant.GetPositionsAndVelocities(com_constraint_context[context_index])):
                ad_plant.SetPositionsAndVelocities(com_constraint_context[context_index], qv)
            com_q = ad_plant.CalcCenterOfMassPositionInWorld(com_constraint_context[context_index], [littledog])
            H_qv = ad_plant.CalcSpatialMomentumInWorldAboutPoint(com_constraint_context[context_index], [littledog], com).rotational()
        else:
            if not np.array_equal(qv, plant.GetPositionsAndVelocities(context[context_index])):
                plant.SetPositionsAndVelocities(context[context_index], qv)
            com_q = plant.CalcCenterOfMassPositionInWorld(context[context_index], [littledog])
            H_qv = plant.CalcSpatialMomentumInWorldAboutPoint(context[context_index], [littledog], com).rotational()
        return np.concatenate((com_q - com, H_qv - H))
    for n in range(N):
        prog.AddConstraint(partial(com_constraint, context_index=n),
            lb=np.zeros(6), ub=np.zeros(6), vars=np.concatenate((q[:,n], v[:,n], com[:,n], H[:,n])))

    # TODO: Add collision constraints

    # Kinematic constraints
    """
    def fixed_position_constraint(vars, context_index, frame):
        q, qn = np.split(vars, [nq])
        if not np.array_equal(q, plant.GetPositions(context[context_index])):
            plant.SetPositions(context[context_index], q)
        if not np.array_equal(qn, plant.GetPositions(context[context_index+1])):
            plant.SetPositions(context[context_index+1], qn)
        # TODO (ethan): might need to change this to be frame of bridge? idk
        p_WF = plant.CalcPointsPositions(context[context_index], frame, [0,0,0], plant.GetFrameByName("bridge_frame"))
        p_WF_n = plant.CalcPointsPositions(context[context_index+1], frame, [0,0,0], plant.GetFrameByName("bridge_frame"))
        if isinstance(vars[0], AutoDiffXd):
            J_WF = plant.CalcJacobianTranslationalVelocity(context[context_index], JacobianWrtVariable.kQDot,
                                                    frame, [0, 0, 0], plant.GetFrameByName("bridge_frame"), plant.GetFrameByName("bridge_frame"))
            J_WF_n = plant.CalcJacobianTranslationalVelocity(context[context_index+1], JacobianWrtVariable.kQDot,
                                                    frame, [0, 0, 0], plant.GetFrameByName("bridge_frame"), plant.GetFrameByName("bridge_frame"))
            return InitializeAutoDiff(
                p_WF_n - p_WF, J_WF_n @ ExtractGradient(qn) - J_WF @ ExtractGradient(q))
        else:
            return p_WF_n - p_WF
    for i in range(4):
        for n in range(N):
            if in_stance[i, n]:
                # foot should be on the ground (world position z=0)
                # TODO (ethan): change to height function (height from bridge == 0) - downward projection distance
                prog.AddConstraint(PositionConstraint(
                    plant, plant.GetFrameByName("bridge_frame"), [-np.inf,-np.inf,0.05], [np.inf,np.inf,0.05],
                    foot_frame[i], [0,0,0], context[n]), q[:,n])
                if n > 0 and in_stance[i, n-1]:
                    # feet should not move during stance.

                    #TODO (ethan): unsure if this needs to be modified
                    prog.AddConstraint(partial(fixed_position_constraint, context_index=n-1, frame=foot_frame[i]),
                                       lb=np.zeros(3), ub=np.zeros(3), vars=np.concatenate((q[:,n-1], q[:,n])))
            else:
                min_clearance = 0.01
                prog.AddConstraint(PositionConstraint(plant, plant.GetFrameByName("bridge_frame"), [-np.inf,-np.inf,0.05+min_clearance], [np.inf,np.inf,np.inf],foot_frame[i],[0,0,0],context[n]), q[:,n])
    """
    """
    # constraint foot relative position
    relative_foot_context = [ad_plant.CreateDefaultContext() for i in range(N)]
    def relative_foot_constraint(vars, context_index):
        q = vars
        if isinstance(vars[0], AutoDiffXd):
            if not autoDiffArrayEqual(q, ad_plant.GetPositions(relative_foot_context[context_index])):
                ad_plant.SetPositions(relative_foot_context[context_index], q)
            ys = []
            for name in ["front_left_foot_center", "front_right_foot_center", "back_left_foot_center", "back_right_foot_center"]:
                ys.append(ad_plant.GetFrameByName(name).CalcPoseInWorld(relative_foot_context[context_index]).translation()[1])
            return np.array([ys[0] - ys[1], ys[2] - ys[3]])
        else:
            if not np.array_equal(qv, plant.GetPositionsAndVelocities(context[context_index])):
                plant.SetPositions(context[context_index], q)
            ys = []
            for name in ["front_left_foot_center", "front_right_foot_center", "back_left_foot_center", "back_right_foot_center"]:
                ys.append(plant.GetFrameByName(name).CalcPoseInWorld(relative_foot_context[context_index]).translation()[1])
            return np.array([ys[0] - ys[1], ys[2] - ys[3]])
            
    
    for n in range(N):
        prog.AddConstraint(partial(relative_foot_constraint, context_index=n),
        lb=np.array([0, 0]), ub=np.array([np.inf, np.inf]), vars=q[:, n])
    """
    # Periodicity constraints
    if is_laterally_symmetric:
        # Joints
        def AddAntiSymmetricPair(a, b):
            prog.AddLinearEqualityConstraint(a[0] == -b[-1])
            prog.AddLinearEqualityConstraint(a[-1] == -b[0])
        def AddSymmetricPair(a, b):
            prog.AddLinearEqualityConstraint(a[0] == b[-1])
            prog.AddLinearEqualityConstraint(a[-1] == b[0])

        AddAntiSymmetricPair(q_view.front_left_hip_roll,
                             q_view.front_right_hip_roll)
        AddSymmetricPair(q_view.front_left_hip_pitch,
                         q_view.front_right_hip_pitch)
        AddSymmetricPair(q_view.front_left_knee, q_view.front_right_knee)
        AddAntiSymmetricPair(q_view.back_left_hip_roll,
                             q_view.back_right_hip_roll)
        AddSymmetricPair(q_view.back_left_hip_pitch,
                         q_view.back_right_hip_pitch)
        AddSymmetricPair(q_view.back_left_knee, q_view.back_right_knee)
        prog.AddLinearEqualityConstraint(q_view.rot1[0] == -q_view.rot1[-1])
        prog.AddLinearEqualityConstraint(v_view.rot1[0] == -v_view.rot1[-1])
        prog.AddLinearEqualityConstraint(q_view.body_y[0] == -q_view.body_y[-1])
        prog.AddLinearEqualityConstraint(q_view.body_z[0] == q_view.body_z[-1])
        # Body orientation must be in the xz plane:
        prog.AddBoundingBoxConstraint(0, 0, q_view.body_qx[[0,-1]])
        prog.AddBoundingBoxConstraint(0, 0, q_view.body_qz[[0,-1]])

        # Floating base velocity
        prog.AddLinearEqualityConstraint(v_view.body_vx[0] == v_view.body_vx[-1])
        prog.AddLinearEqualityConstraint(v_view.body_vy[0] == -v_view.body_vy[-1])
        prog.AddLinearEqualityConstraint(v_view.body_vz[0] == v_view.body_vz[-1])

        # CoM velocity
        prog.AddLinearEqualityConstraint(comdot[0,0] == comdot[0,-1])
        prog.AddLinearEqualityConstraint(comdot[1,0] == -comdot[1,-1])
        prog.AddLinearEqualityConstraint(comdot[2,0] == comdot[2,-1])

    else:
        # Everything except body_x is periodic
        q_selector = PositionView([True]*nq)
        q_selector.body_x = False
        # make bridge periodic
        q_selector.rot1 = False
        prog.AddLinearConstraint(eq(q[q_selector,0], q[q_selector,-1]))
        prog.AddLinearConstraint(eq(v[:,0], v[:,-1]))

    # TODO: Set solver parameters (mostly to make the worst case solve times less bad)
    snopt = SnoptSolver().solver_id()
    if initial_guess is not None:
        print('Overriding initial guess to the provided')
        prog.SetInitialGuessForAllVariables(initial_guess)
    prog.SetSolverOption(snopt, 'Iterations Limits', 1e5 if running_as_notebook else 1)
    prog.SetSolverOption(snopt, 'Major Iterations Limit', 200 if running_as_notebook else 1)
    major_feasibility_tolerance = 5e-5
    prog.SetSolverOption(snopt, 'Major Feasibility Tolerance', major_feasibility_tolerance)
    prog.SetSolverOption(snopt, 'Major Optimality Tolerance', 1e-4)
    prog.SetSolverOption(snopt, 'Superbasics limit', 2000)
    prog.SetSolverOption(snopt, 'Linesearch tolerance', 0.9)
    #prog.SetSolverOption(snopt, 'Print file', 'snopt.out')

    # TODO a few more costs/constraints from
    # from https://github.com/RobotLocomotion/LittleDog/blob/master/gaitOptimization.m
    print("starting solver")

    print('Check Satisfied at initial guess:', prog.CheckSatisfiedAtInitialGuess(prog.GetAllConstraints(), major_feasibility_tolerance))
    result = Solve(prog)
    print('Solver name:', result.get_solver_id().name())
    print('Solver result:', result.is_success())  # We expect this to be false if iterations are limited.
    print('Solver infeasible constraints:', result.GetInfeasibleConstraints(prog, 5e-6))
    print(result.GetInfeasibleConstraintNames(prog, 5e-6))
    def HalfStrideToFullStride(a):
        b = PositionView(np.copy(a))

        b.body_y = -a.body_y
        # Mirror quaternion so that roll=-roll, yaw=-yaw
        b.body_qx = -a.body_qx
        b.body_qz = -a.body_qz

        b.front_left_hip_roll = -a.front_right_hip_roll
        b.front_right_hip_roll = -a.front_left_hip_roll
        b.back_left_hip_roll = -a.back_right_hip_roll
        b.back_right_hip_roll = -a.back_left_hip_roll

        b.front_left_hip_pitch = a.front_right_hip_pitch
        b.front_right_hip_pitch = a.front_left_hip_pitch
        b.back_left_hip_pitch = a.back_right_hip_pitch
        b.back_right_hip_pitch = a.back_left_hip_pitch

        b.front_left_knee = a.front_right_knee
        b.front_right_knee = a.front_left_knee
        b.back_left_knee = a.back_right_knee
        b.back_right_knee = a.back_left_knee

        b.rot1 = -a.rot1

        return b


    # Animate trajectory
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyContextFromRoot(context)
    t_sol = np.cumsum(np.concatenate(([0],result.GetSolution(h))))
    q_sol = PiecewisePolynomial.FirstOrderHold(t_sol, result.GetSolution(q))
    visualizer.StartRecording()
    num_strides = 4
    t0 = t_sol[0]
    tf = t_sol[-1]
    T = tf*num_strides*(2.0 if is_laterally_symmetric else 1.0)
    for t in np.hstack((np.arange(t0, T, 1.0/32.0), T)):
        context.SetTime(t)
        stride = (t - t0) // (tf - t0)
        ts = (t - t0) % (tf - t0)
        qt = PositionView(q_sol.value(ts))
        if is_laterally_symmetric:
            if stride % 2 == 1:
                qt = HalfStrideToFullStride(qt)
                qt.body_x += stride_length/2.0
            stride = stride // 2
        qt.body_x += stride*stride_length
        plant.SetPositions(plant_context, qt[:])
        diagram.Publish(context)

    visualizer.StopRecording()
    visualizer.PublishRecording()
    return result

# Try them all!  The last two could use a little tuning.
gait_optimization('walking_trot', 0, result).GetSolution()
# for i in range(6):
    # result = gait_optimization('walking_trot', i * 0.01, result).GetSolution()
# gait_optimization('running_trot')
# gait_optimization('rotary_gallop')
# gait_optimization('bound')
# Out:
# [ 0.          0.00018405 -0.00953257]
# [[0.]
#  [0.]
#  [1.]]
# [[0.01 0.   0.  ]
#  [0.   0.01 0.  ]
#  [0.   0.   0.01]]
# q0 home positions: [ 0.     1.     0.     0.     0.     0.     0.     1.346  0.1    1.
#  -1.55  -0.1    1.    -1.55   0.1   -1.     1.55  -0.1   -1.     1.55 ]
# Entering MakeNamedViewPositions
# joint name front_left_hip_roll joint.num_positions 1
# joint name front_left_hip_pitch joint.num_positions 1
# joint name front_left_knee joint.num_positions 1
# joint name front_right_hip_roll joint.num_positions 1
# joint name front_right_hip_pitch joint.num_positions 1
# joint name front_right_knee joint.num_positions 1
# joint name back_left_hip_roll joint.num_positions 1
# joint name back_left_hip_pitch joint.num_positions 1
# joint name back_left_knee joint.num_positions 1
# joint name back_right_hip_roll joint.num_positions 1
# joint name back_right_hip_pitch joint.num_positions 1
# joint name back_right_knee joint.num_positions 1
# joint name rot1 joint.num_positions 1
# Exiting MakeNamedViewPositions
# ('rot1', 'body_qw', 'body_qx', 'body_qy', 'body_qz', 'body_x', 'body_y', 'body_z', 'front_left_hip_roll', 'front_left_hip_pitch', 'front_left_knee', 'front_right_hip_roll', 'front_right_hip_pitch', 'front_right_knee', 'back_left_hip_roll', 'back_left_hip_pitch', 'back_left_knee', 'back_right_hip_roll', 'back_right_hip_pitch', 'back_right_knee')
# Overriding initial guess to the provided
# starting solver
# Check Satisfied at initial guess: False
# Solver name: SNOPT/fortran
# Solver result: True
# Solver infeasible constraints: [<pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f20299d07b0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7970>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f20299d0930>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7b30>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7af0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7f70>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7d30>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa72b0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa78b0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7070>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7e30>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7eb0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7170>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7d70>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7330>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7670>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7ab0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa76b0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7bf0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa75b0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7270>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7c70>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7430>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7470>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa78f0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7230>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7bb0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa74f0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa77b0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa71f0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7fb0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7130>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7630>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7db0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa71b0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa77f0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa72f0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7870>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7930>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7570>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7f30>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa73f0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa79f0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7730>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa75f0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f2029aa7770>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7f20299d7170>, <pydrake.solvers.mat ...
# ['drake::pydrake::(anonymous)::PyFunctionConstraint[3]: 0.000000 <= 0.000006 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[7]: 0.000000 <= -0.000058 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[8]: 0.000000 <= 0.000059 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[10]: 0.000000 <= 0.000018 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[13]: 0.000000 <= 0.000042 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[14]: 0.000000 <= -0.000104 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[15]: 0.000000 <= -0.000128 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[16]: 0.000000 <= 0.000024 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[7]: 0.000000 <= 0.000030 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[8]: 0.000000 <= -0.000026 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[9]: 0.000000 <= -0.000012 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[10]: 0.000000 <= -0.000011 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[13]: 0.000000 <= 0.000017 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[14]: 0.000000 <= -0.000045 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[15]: 0.000000 <= -0.000053 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[16]: 0.000000 <= -0.000016 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[17]: 0.000000 <= -0.000011 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[3]: 0.000000 <= 0.000018 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[7]: 0.000000 <= -0.000017 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[8]: 0.000000 <= -0.000226 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[9]: 0.000000 <= -0.000079 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[10]: 0.000000 <= 0.000083 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[11]: 0.000000 <= 0.000068 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[12]: 0.000000 <= 0.000011 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[14]: 0.000000 <= 0.000265 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[15]: 0.000000 <= 0.000198 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[16]: 0.000000 <= -0.000106 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[17]: 0.000000 <= -0.000224 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[18]: 0.000000 <= -0.000019 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[3]: 0.000000 <= 0.000007 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[7]: 0.000000 <= 0.000010 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[8]: 0.000000 <= 0.000049 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[9]: 0.000000 <= 0.000006 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[10]: 0.000000 <= 0.000050 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[11]: 0.000000 <= 0.000111 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[12]: 0.000000 <= -0.000007 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[13]: 0.000000 <= 0.000183 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[14]: 0.000000 <= -0.000229 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[15]: 0.000000 <= -0.000133 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[16]: 0.000000 <= 0.000038 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[17]: 0.000000 <= 0.000305 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[18]: 0.000000 <= 0.000193 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[1]: 0.000000 <= 0.000005 <= 0.000000', 'drake::pydrake::(anonymous)::PyFunctionConstraint[7]: 0.000000 <= 0.000008 <= 0.0 ...
# array([ 0.0297619 ,  0.0297619 ,  0.02972577, ...,  0.01448933,
#         0.0019148 , -0.0086832 ])

# %% [markdown]
# Welp let's try the mixed integer program anyway

# %%
# TODO (kenneth): allow kinetic friction, stop relying on pre-specified mode sequence

def set_home(plant, context, ground_angle):
    # used in traj optimization for setting initial quess positions
    hip_roll = .1;
    hip_pitch = 1;
    knee = 1.55;
    plant.GetJointByName("front_right_hip_roll").set_angle(context, -hip_roll)
    plant.GetJointByName("front_right_hip_pitch").set_angle(context, hip_pitch)
    plant.GetJointByName("front_right_knee").set_angle(context, -knee)
    plant.GetJointByName("front_left_hip_roll").set_angle(context, hip_roll)
    plant.GetJointByName("front_left_hip_pitch").set_angle(context, hip_pitch)
    plant.GetJointByName("front_left_knee").set_angle(context, -knee)
    plant.GetJointByName("back_right_hip_roll").set_angle(context, -hip_roll)
    plant.GetJointByName("back_right_hip_pitch").set_angle(context, -hip_pitch)
    plant.GetJointByName("back_right_knee").set_angle(context, knee)
    plant.GetJointByName("back_left_hip_roll").set_angle(context, hip_roll)
    plant.GetJointByName("back_left_hip_pitch").set_angle(context, -hip_pitch)
    plant.GetJointByName("back_left_knee").set_angle(context, knee)
    plant.SetFreeBodyPose(context, plant.GetBodyByName("body"), RigidTransform([0, 0, 1.346]))
    # plant.SetFreeBodyPose(context, plant.GetBodyByName("body"), RigidTransform([0, 0, 0.146]))
    plant.GetJointByName("rot1").set_angle(context, ground_angle)

# Need this because a==b returns True even if a = AutoDiffXd(1, [1, 2]), b= AutoDiffXd(2, [3, 4])
# That's the behavior of AutoDiffXd in C++, also.
def autoDiffArrayEqual(a,b):
    return np.array_equal(a, b) and np.array_equal(ExtractGradient(a), ExtractGradient(b))

# TODO: promote this to drake (and make a version with model_instance)
def MakeNamedViewPositions(mbp, view_name):
    names = [None]*mbp.num_positions()
    print("Entering MakeNamedViewPositions")
    for ind in range(mbp.num_joints()):
        joint = mbp.get_joint(JointIndex(ind))
        if joint.num_positions() == 0:
            # skip weld joints
            continue
        print('joint name', joint.name(), 'joint.num_positions', joint.num_positions())
        # TODO: Handle planar joints, etc.
        # assert(joint.num_positions() == 1)
        names[joint.position_start()] = joint.name()
    
    for ind in mbp.GetFloatingBaseBodies():
        body = mbp.get_body(ind)
        start = body.floating_positions_start()
        body_name = body.name()
        names[start] = body_name+'_qw'
        names[start+1] = body_name+'_qx'
        names[start+2] = body_name+'_qy'
        names[start+3] = body_name+'_qz'
        names[start+4] = body_name+'_x'
        names[start+5] = body_name+'_y'
        names[start+6] = body_name+'_z'
    print("Exiting MakeNamedViewPositions")
    return namedview(view_name, names)

def MakeNamedViewVelocities(mbp, view_name):
    names = [None]*mbp.num_velocities()
    for ind in range(mbp.num_joints()):
        joint = mbp.get_joint(JointIndex(ind))
        if joint.num_positions() == 0:
            # skip weld joints
            continue
        # print('joint name', joint.name(), 'joint.num_positions', joint.num_positions())
        # TODO: Handle planar joints, etc.
        # assert(joint.num_velocities() == 1)
        names[joint.velocity_start()] = joint.name()
    for ind in mbp.GetFloatingBaseBodies():
        body = mbp.get_body(ind)
        start = body.floating_velocities_start() - mbp.num_positions()
        body_name = body.name()
        names[start] = body_name+'_wx'
        names[start+1] = body_name+'_wy'
        names[start+2] = body_name+'_wz'
        names[start+3] = body_name+'_vx'
        names[start+4] = body_name+'_vy'
        names[start+5] = body_name+'_vz'
    return namedview(view_name, names)

def gait_optimization(gait = 'walking_trot', ground_angle=0, initial_guess=None):
    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, 1e-3)
    parser = Parser(plant)
    littledog = parser.AddModelFromFile(FindResource('models/littledog/LittleDog.urdf'))
    bridge = parser.AddModelFromFile('./ground.urdf')
    plant.Finalize()
    visualizer = MeshcatVisualizerCpp.AddToBuilder(builder, scene_graph,
                                                   meshcat)

    diagram = builder.Build()
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyContextFromRoot(context)
    set_home(plant, plant_context, ground_angle)
    diagram.Publish(context)
    print(plant.CalcCenterOfMassPositionInWorld(plant.CreateDefaultContext(), [littledog]))
    print(plant.GetBodyByName("ground").EvalPoseInWorld(plant_context).rotation().inverse().multiply(np.array([[0.0, 0.0, 1.0]]).T))
    print(np.linalg.inv(plant.GetBodyByName("ground").CalcSpatialInertiaInBodyFrame(plant_context).CalcRotationalInertia().CopyToFullMatrix3()))
    # raise RuntimeError()

    q0 = plant.GetPositions(plant_context)
    print('q0 home positions:', q0)
    body_frame = plant.GetFrameByName("body")

    PositionView = MakeNamedViewPositions(plant, "Positions")
    VelocityView = MakeNamedViewVelocities(plant, "Velocities")

    mu = 1 # rubber on rubber
    total_mass = sum(plant.get_body(index).get_mass(context) for index in plant.GetBodyIndices(littledog))
    gravity = plant.gravity_field().gravity_vector()

    nq = 12
    foot_frame = [
        plant.GetFrameByName('front_left_foot_center'),
        plant.GetFrameByName('front_right_foot_center'),
        plant.GetFrameByName('back_left_foot_center'),
        plant.GetFrameByName('back_right_foot_center')]

    # setup gait
    is_laterally_symmetric = False
    check_self_collision = False
    if gait == 'running_trot':
        N = 21
        in_stance = np.zeros((4, N))
        in_stance[1, 3:17] = 1
        in_stance[2, 3:17] = 1
        speed = 0.9
        stride_length = .55
        is_laterally_symmetric = True
    elif gait == 'walking_trot':
        N = 81
        in_stance = np.zeros((4, N))
        in_stance[0, :11] = 1
        in_stance[1, 8:N] = 1
        in_stance[2, 8:N] = 1
        in_stance[3, :11] = 1
        speed = 0.25
        stride_length = 0.4
        is_laterally_symmetric = False
    elif gait == 'rotary_gallop':
        N = 41
        in_stance = np.zeros((4, N))
        in_stance[0, 7:19] = 1
        in_stance[1, 3:15] = 1
        in_stance[2, 24:35] = 1
        in_stance[3, 26:38] = 1
        speed = 1
        stride_length = .65
        check_self_collision = True
    elif gait == 'bound':
        N = 41
        in_stance = np.zeros((4, N))
        in_stance[0, 6:18] = 1
        in_stance[1, 6:18] = 1
        in_stance[2, 21:32] = 1
        in_stance[3, 21:32] = 1
        speed = 1.2
        stride_length = .55
        check_self_collision = True
    else:
        raise RuntimeError('Unknown gait.')


    T = stride_length / speed
    if is_laterally_symmetric:
        T = T / 2.0

    prog = MathematicalProgram()

    # Time steps
    h = prog.NewContinuousVariables(N-1, "h")
    prog.AddBoundingBoxConstraint(0.5*T/N, 2.0*T/N, h)
    prog.AddLinearConstraint(sum(h) >= .9*T)
    prog.AddLinearConstraint(sum(h) <= 1.1*T)

    # Create one context per timestep (to maximize cache hits)
    context = [plant.CreateDefaultContext() for i in range(N)]
    # We could get rid of this by implementing a few more Jacobians in MultibodyPlant:
    ad_plant = plant.ToAutoDiffXd()

    # Joint positions and velocities

    # 20 positions - 19 for the dog, 1 for the bridge joint (note that the bridge joint is index 0)
    nq = plant.num_positions()
    # 19 velocities (not sure why there's one less)
    nv = plant.num_velocities()
    q = prog.NewContinuousVariables(nq, N, "q")
    v = prog.NewContinuousVariables(nv, N, "v")

    # for n in range(N):
        
    #     prog.AddLinearConstraint(q[0, n] == 0)
    #     prog.AddLinearConstraint(v[0, n] == 0)

    q_view = PositionView(q)
    print(q_view.get_fields())
    v_view = VelocityView(v)
    q0_view = PositionView(q0)
    # Joint costs
    q_cost = PositionView([1]*nq)
    v_cost = VelocityView([1]*nv)
    q_cost.body_x = 0
    q_cost.body_y = 0
    q_cost.body_qx = 0
    q_cost.body_qy = 0
    q_cost.body_qz = 0
    q_cost.body_qw = 0
    q_cost.front_left_hip_roll = 5
    q_cost.front_right_hip_roll = 5
    q_cost.back_left_hip_roll = 5
    q_cost.back_right_hip_roll = 5
    v_cost.body_vx = 0
    v_cost.body_wx = 0
    v_cost.body_wy = 0
    v_cost.body_wz = 0

    for n in range(N):
        # Joint limits
        # limits are -inf and inf for ind 0 (bridge joint)
        prog.AddBoundingBoxConstraint(plant.GetPositionLowerLimits()[8:], plant.GetPositionUpperLimits()[8:], q[8:,n])
        # Joint velocity limits
        prog.AddBoundingBoxConstraint(plant.GetVelocityLowerLimits()[8:], plant.GetVelocityUpperLimits()[8:], v[8:,n])
        # Unit quaternions
        AddUnitQuaternionConstraintOnPlant(plant, q[:,n], prog)
        # Body orientation
        # prog.AddConstraint(OrientationConstraint(plant,
        #                                          body_frame, RotationMatrix(),
        #                                          plant.world_frame(), RotationMatrix(),
        #                                          0.1, context[n]), q[:,n])
        # Initial guess for all joint angles is the home position
        prog.SetInitialGuess(q[:,n], q0)  # Solvers get stuck if the quaternion is initialized with all zeros.

        # Running costs:
        prog.AddQuadraticErrorCost(np.diag(q_cost), q0, q[:,n])
        prog.AddQuadraticErrorCost(np.diag(v_cost), [0]*nv, v[:,n])

    # Make a new autodiff context for this constraint (to maximize cache hits)
    ad_velocity_dynamics_context = [ad_plant.CreateDefaultContext() for i in range(N)]
    def velocity_dynamics_constraint(vars, context_index):
        # constraint so that differences in current position and next position is correct velocity
        h, q, v, qn = np.split(vars, [1, 1+nq, 1+nq+nv])
        if isinstance(vars[0], AutoDiffXd):
            if not autoDiffArrayEqual(q, ad_plant.GetPositions(ad_velocity_dynamics_context[context_index])):
                ad_plant.SetPositions(ad_velocity_dynamics_context[context_index], q)
            v_from_qdot = ad_plant.MapQDotToVelocity(ad_velocity_dynamics_context[context_index], (qn - q)/h)
        else:
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            v_from_qdot = plant.MapQDotToVelocity(context[context_index], (qn - q)/h)
        return v - v_from_qdot
    for n in range(N-1):
        prog.AddConstraint(
            partial(velocity_dynamics_constraint, context_index=n),
            lb=[0]*nv, ub=[0]*nv,
            vars=np.concatenate(([h[n]], q[:,n], v[:,n], q[:,n+1])))

    # Contact forces
    contact_force = [prog.NewContinuousVariables(3, N-1, f"foot{foot}_contact_force") for foot in range(4)]
    ad_contact_force_context = [ad_plant.CreateDefaultContext() for i in range(N - 1)]
    def contact_force_constraint(vars, context_index):
        q, foot_force = np.split(vars, [nq])
        # Linear friction cone
        if isinstance(vars[0], AutoDiffXd):
            if not autoDiffArrayEqual(q, ad_plant.GetPositions(ad_contact_force_context[context_index])):
                ad_plant.SetPositions(ad_contact_force_context[context_index], q)
            rel_contact = ad_plant.GetBodyByName("ground").EvalPoseInWorld(ad_contact_force_context[context_index]).rotation().inverse().multiply(foot_force.reshape((-1, 1)))[:, 0]
        else:
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            rel_contact = plant.GetBodyByName("ground").EvalPoseInWorld(context[context_index]).rotation().inverse().multiply(foot_force.reshape((-1, 1)))[:, 0]
        return np.array([
            mu*rel_contact[2] - rel_contact[0],
            mu*rel_contact[2] + rel_contact[0],
            mu*rel_contact[2] - rel_contact[1],
            mu*rel_contact[2] + rel_contact[1],
        ])
    
    for n in range(N-1):
        for foot in range(4):
            prog.AddConstraint(
                partial(contact_force_constraint, context_index=n),
                lb=[0]*4, ub=[np.inf]*4,
                vars=np.concatenate((q[:,n], contact_force[foot][:,n])))

    # set bridge initial condition (just set to be whatever it is in q0 from sethome)
    prog.AddLinearConstraint(q[0, 0]==q0[0])
    # TODO (ethan): add bridge force calculation from contact forces
    # TODO (ethan): enforce bridge rotaation due to gravity
    

    # Center of mass variables and constraints
    com = prog.NewContinuousVariables(3, N, "com")
    comdot = prog.NewContinuousVariables(3, N, "comdot")
    comddot = prog.NewContinuousVariables(3, N-1, "comddot")
    # Initial CoM x,y position == 0
    # TODO (ethan): change start position
    prog.AddBoundingBoxConstraint(0, 0, com[:2,0])
    # Initial CoM z vel == 0
    prog.AddBoundingBoxConstraint(0, 0, comdot[:,0])
    # CoM height
    # TODO (ethan): change height constraint
    # prog.AddBoundingBoxConstraint(1, 1.5, com[2,:])
    # CoM x velocity >= 0
    prog.AddBoundingBoxConstraint(0, np.inf, comdot[0,:])
    # CoM final x position
    # TODO (ethan): change final position constraint
    if is_laterally_symmetric:
        prog.AddBoundingBoxConstraint(stride_length/2.0, stride_length/2.0, com[0,-1])
    else:
        prog.AddBoundingBoxConstraint(stride_length, stride_length, com[0,-1])
    # CoM dynamics
    for n in range(N-1):
        # Note: The original matlab implementation used backwards Euler (here and throughout),
        # which is a little more consistent with the LCP contact models.
        prog.AddConstraint(eq(com[:, n+1], com[:,n] + h[n]*comdot[:,n]))
        prog.AddConstraint(eq(comdot[:, n+1], comdot[:,n] + h[n]*comddot[:,n]))
        prog.AddConstraint(eq(total_mass*comddot[:,n], sum(contact_force[i][:,n] for i in range(4)) + total_mass*gravity))

    # Angular momentum (about the center of mass)
    H = prog.NewContinuousVariables(3, N, "H")
    Hdot = prog.NewContinuousVariables(3, N-1, "Hdot")
    prog.SetInitialGuess(H, np.zeros((3, N)))
    prog.SetInitialGuess(Hdot, np.zeros((3,N-1)))
    # Hdot = sum_i cross(p_FootiW-com, contact_force_i)
    def angular_momentum_constraint(vars, context_index):
        q, com, Hdot, contact_force = np.split(vars, [nq, nq+3, nq+6])
        contact_force = contact_force.reshape(3, 4, order='F')
        if isinstance(vars[0], AutoDiffXd):
            q = ExtractValue(q)
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            torque = np.zeros(3)
            for i in range(4):
                p_WF = plant.CalcPointsPositions(context[context_index], foot_frame[i], [0,0,0], plant.world_frame())
                Jq_WF = plant.CalcJacobianTranslationalVelocity(
                    context[context_index], JacobianWrtVariable.kQDot,
                    foot_frame[i], [0, 0, 0], plant.world_frame(), plant.world_frame())
                ad_p_WF = InitializeAutoDiff(p_WF, np.hstack((Jq_WF, np.zeros((3, 18)))))
                torque = torque + np.cross(ad_p_WF.reshape(3) - com, contact_force[:,i])
        else:
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            torque = np.zeros(3)
            for i in range(4):
                p_WF = plant.CalcPointsPositions(context[context_index], foot_frame[i], [0,0,0], plant.world_frame())
                torque += np.cross(p_WF.reshape(3) - com, contact_force[:,i])
        return Hdot - torque
    for n in range(N-1):
        prog.AddConstraint(eq(H[:,n+1], H[:,n] + h[n]*Hdot[:,n]))
        Fn = np.concatenate([contact_force[i][:,n] for i in range(4)])
        prog.AddConstraint(partial(angular_momentum_constraint, context_index=n), lb=np.zeros(3), ub=np.zeros(3),
                           vars=np.concatenate((q[:,n], com[:,n], Hdot[:,n], Fn)))
    
    BrVdot = prog.NewContinuousVariables(N-1, "BrVdot")
    def bridge_angular_momentum_constraint(vars, context_index):
        q, BrVdot, contact_force = np.split(vars, [nq, nq+1])
        contact_force = contact_force.reshape(3, 4, order='F')
        bridge_com = np.array([0, 0, 1]) # TODO (kenneth): don't hard-code the com of the bridge
        bridge_inertia = plant.GetBodyByName("ground").CalcSpatialInertiaInBodyFrame(plant_context).CalcRotationalInertia().CopyToFullMatrix3()
        if isinstance(vars[0], AutoDiffXd):
            q = ExtractValue(q)
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            torque_bridge = np.zeros(3)
            for i in range(4):
                p_WF = plant.CalcPointsPositions(context[context_index], foot_frame[i], [0,0,0], plant.world_frame())
                Jq_WF = plant.CalcJacobianTranslationalVelocity(
                    context[context_index], JacobianWrtVariable.kQDot,
                    foot_frame[i], [0, 0, 0], plant.world_frame(), plant.world_frame())
                ad_p_WF = InitializeAutoDiff(p_WF, np.hstack((Jq_WF, np.zeros((3, 18)))))
                torque_bridge = torque_bridge + np.cross(ad_p_WF.reshape(3) - bridge_com, contact_force[:,i])
        else:
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            torque_bridge = np.zeros(3)
            for i in range(4):
                p_WF = plant.CalcPointsPositions(context[context_index], foot_frame[i], [0,0,0], plant.world_frame())
                torque_bridge += np.cross(p_WF.reshape(3) - bridge_com, contact_force[:,i])
        # we use the Ixx entry in the inertia matrix, since the bridge spins along the x axis
        return bridge_inertia[0, 0] * BrVdot - torque_bridge.dot(np.array([1, 0, 0])) # TODO (kenneth): replace np array with bridge axis
    for n in range(N-1):
        prog.AddConstraint(v_view.rot1[n+1] == v_view.rot1[n] + h[n]*BrVdot[n])
        Fn = np.concatenate([contact_force[i][:,n] for i in range(4)])
        prog.AddConstraint(partial(bridge_angular_momentum_constraint, context_index=n), lb=np.zeros(1), ub=np.zeros(1),
                           vars=np.concatenate((q[:,n], [BrVdot[n]], Fn)))

    # com == CenterOfMass(q), H = SpatialMomentumInWorldAboutPoint(q, v, com)
    # Make a new autodiff context for this constraint (to maximize cache hits)
    com_constraint_context = [ad_plant.CreateDefaultContext() for i in range(N)]
    def com_constraint(vars, context_index):
        qv, com, H = np.split(vars, [nq+nv, nq+nv+3])
        if isinstance(vars[0], AutoDiffXd):
            if not autoDiffArrayEqual(qv, ad_plant.GetPositionsAndVelocities(com_constraint_context[context_index])):
                ad_plant.SetPositionsAndVelocities(com_constraint_context[context_index], qv)
            com_q = ad_plant.CalcCenterOfMassPositionInWorld(com_constraint_context[context_index], [littledog])
            H_qv = ad_plant.CalcSpatialMomentumInWorldAboutPoint(com_constraint_context[context_index], [littledog], com).rotational()
        else:
            if not np.array_equal(qv, plant.GetPositionsAndVelocities(context[context_index])):
                plant.SetPositionsAndVelocities(context[context_index], qv)
            com_q = plant.CalcCenterOfMassPositionInWorld(context[context_index], [littledog])
            H_qv = plant.CalcSpatialMomentumInWorldAboutPoint(context[context_index], [littledog], com).rotational()
        return np.concatenate((com_q - com, H_qv - H))
    for n in range(N):
        prog.AddConstraint(partial(com_constraint, context_index=n),
            lb=np.zeros(6), ub=np.zeros(6), vars=np.concatenate((q[:,n], v[:,n], com[:,n], H[:,n])))

    # TODO: Add collision constraints

    # Kinematic constraints
    """
    def fixed_position_constraint(vars, context_index, frame):
        q, qn = np.split(vars, [nq])
        if not np.array_equal(q, plant.GetPositions(context[context_index])):
            plant.SetPositions(context[context_index], q)
        if not np.array_equal(qn, plant.GetPositions(context[context_index+1])):
            plant.SetPositions(context[context_index+1], qn)
        # TODO (ethan): might need to change this to be frame of bridge? idk
        p_WF = plant.CalcPointsPositions(context[context_index], frame, [0,0,0], plant.GetFrameByName("bridge_frame"))
        p_WF_n = plant.CalcPointsPositions(context[context_index+1], frame, [0,0,0], plant.GetFrameByName("bridge_frame"))
        if isinstance(vars[0], AutoDiffXd):
            J_WF = plant.CalcJacobianTranslationalVelocity(context[context_index], JacobianWrtVariable.kQDot,
                                                    frame, [0, 0, 0], plant.GetFrameByName("bridge_frame"), plant.GetFrameByName("bridge_frame"))
            J_WF_n = plant.CalcJacobianTranslationalVelocity(context[context_index+1], JacobianWrtVariable.kQDot,
                                                    frame, [0, 0, 0], plant.GetFrameByName("bridge_frame"), plant.GetFrameByName("bridge_frame"))
            return InitializeAutoDiff(
                p_WF_n - p_WF, J_WF_n @ ExtractGradient(qn) - J_WF @ ExtractGradient(q))
        else:
            return p_WF_n - p_WF
    """

    comp_ground_context = [ad_plant.CreateDefaultContext() for i in range(N)]
    def complementarity_on_ground_constraint(vars, context_index, frame):
        # contact forces exist iff foot on ground
        a1, a2, q, contact_force = np.split(vars, [1, 2, 2 + nq])
        a1 = a1[0]
        a2 = a2[0]
        contact_force_mag = contact_force.dot(contact_force)
        if isinstance(vars[0], AutoDiffXd):
            if not autoDiffArrayEqual(q, ad_plant.GetPositions(comp_ground_context[context_index])):
                ad_plant.SetPositions(comp_ground_context[context_index], q)
            p_BF = ad_plant.CalcPointsPositions(comp_ground_context[context_index], ad_plant.GetFrameByName(frame.name()), [0,0,0], ad_plant.GetFrameByName("bridge_frame"))
        else:
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            p_BF = plant.CalcPointsPositions(context[context_index], frame, [0,0,0], plant.GetFrameByName("bridge_frame"))
        # guard function is just the z component of the position
        p_BF = p_BF.reshape(-1)
        return np.array([contact_force_mag - a1, p_BF[2] - a2])
    
    comp_slip_context = [ad_plant.CreateDefaultContext() for i in range(N)]
    def complementarity_no_slip_constraint(vars, context_index, frame):
        a3, a4, q, qn, contact_force = np.split(vars, [1, 4, nq + 4, nq + nq + 4])
        a3 = a3[0]
        contact_force_mag = contact_force.dot(contact_force)
        if isinstance(vars[0], AutoDiffXd):
            if not autoDiffArrayEqual(q, ad_plant.GetPositions(comp_slip_context[context_index])):
                ad_plant.SetPositions(comp_slip_context[context_index], q)
            if not autoDiffArrayEqual(qn, ad_plant.GetPositions(comp_slip_context[context_index + 1])):
                ad_plant.SetPositions(comp_slip_context[context_index], qn)
            p_WF = ad_plant.CalcPointsPositions(comp_slip_context[context_index], ad_plant.GetFrameByName(frame.name()), [0,0,0], ad_plant.GetFrameByName("bridge_frame"))
            p_WF_n = ad_plant.CalcPointsPositions(comp_slip_context[context_index+1], ad_plant.GetFrameByName(frame.name()), [0,0,0], ad_plant.GetFrameByName("bridge_frame"))
        else:
            if not np.array_equal(q, plant.GetPositions(context[context_index])):
                plant.SetPositions(context[context_index], q)
            if not np.array_equal(qn, plant.GetPositions(context[context_index + 1])):
                plant.SetPositions(context[context_index + 1], qn)
            p_WF = plant.CalcPointsPositions(context[context_index], frame, [0,0,0], plant.GetFrameByName("bridge_frame"))
            p_WF_n = plant.CalcPointsPositions(context[context_index+1], frame, [0,0,0], plant.GetFrameByName("bridge_frame"))
        p_WF = p_WF.reshape(-1)
        p_WF_n = p_WF_n.reshape(-1)
        return np.concatenate(([contact_force_mag - a3], (p_WF_n - p_WF) - a4))

    a1 = prog.NewContinuousVariables(4, N - 1, "a1")
    a2 = prog.NewContinuousVariables(4, N - 1, "a2")
    a3 = prog.NewContinuousVariables(4, N - 1, "a3")
    a40 = prog.NewContinuousVariables(4, N - 1, "a40")
    a41 = prog.NewContinuousVariables(4, N - 1, "a41")
    a42 = prog.NewContinuousVariables(4, N - 1, "a42")
    for i in range(4):
        for n in range(N-1):
            # for unspecified mode_sequences: contact forces * distance = 0 
            # contact force * foot movement = 0 
            foot_force = contact_force[i][:,n]
            tol = 0
            prog.AddConstraint(partial(complementarity_on_ground_constraint, context_index=n, frame=foot_frame[i]), lb=[-tol] * 2, ub=[tol] * 2, vars=np.concatenate(([a1[i, n]], [a2[i, n]], q[:, n], foot_force)))
            prog.AddConstraint(partial(complementarity_no_slip_constraint, context_index=n, frame=foot_frame[i]), lb=[-tol] * 4, ub=[tol] * 4, vars=np.concatenate(([a3[i, n]], [a40[i, n], a41[i, n], a42[i, n]], q[:, n], q[:,n + 1], foot_force)))
            prog.AddConstraint(a1[i, n] * a2[i, n], 0, 0)
            prog.AddConstraint(a3[i, n] * a40[i, n], 0, 0)
            prog.AddConstraint(a3[i, n] * a41[i, n], 0, 0)
            prog.AddConstraint(a3[i, n] * a42[i, n], 0, 0)
            """
            if in_stance[i, n]:
                # foot should be on the ground (world position z=0)
                # TODO (ethan): change to height function (height from bridge == 0) - downward projection distance
                prog.AddConstraint(PositionConstraint(
                    plant, plant.GetFrameByName("bridge_frame"), [-np.inf,-np.inf,0.05], [np.inf,np.inf,0.05],
                    foot_frame[i], [0,0,0], context[n]), q[:,n])
                if n > 0 and in_stance[i, n-1]:
                    # feet should not move during stance.

                    #TODO (ethan): unsure if this needs to be modified
                    prog.AddConstraint(partial(fixed_position_constraint, context_index=n-1, frame=foot_frame[i]),
                                       lb=np.zeros(3), ub=np.zeros(3), vars=np.concatenate((q[:,n-1], q[:,n])))
            else:
                min_clearance = 0.01
                prog.AddConstraint(PositionConstraint(plant, plant.GetFrameByName("bridge_frame"), [-np.inf,-np.inf,0.05+min_clearance], [np.inf,np.inf,np.inf],foot_frame[i],[0,0,0],context[n]), q[:,n])
            """
    """
    # constraint foot relative position
    relative_foot_context = [ad_plant.CreateDefaultContext() for i in range(N)]
    def relative_foot_constraint(vars, context_index):
        q = vars
        if isinstance(vars[0], AutoDiffXd):
            if not autoDiffArrayEqual(q, ad_plant.GetPositions(relative_foot_context[context_index])):
                ad_plant.SetPositions(relative_foot_context[context_index], q)
            ys = []
            for name in ["front_left_foot_center", "front_right_foot_center", "back_left_foot_center", "back_right_foot_center"]:
                ys.append(ad_plant.GetFrameByName(name).CalcPoseInWorld(relative_foot_context[context_index]).translation()[1])
            return np.array([ys[0] - ys[1], ys[2] - ys[3]])
        else:
            if not np.array_equal(qv, plant.GetPositionsAndVelocities(context[context_index])):
                plant.SetPositions(context[context_index], q)
            ys = []
            for name in ["front_left_foot_center", "front_right_foot_center", "back_left_foot_center", "back_right_foot_center"]:
                ys.append(plant.GetFrameByName(name).CalcPoseInWorld(relative_foot_context[context_index]).translation()[1])
            return np.array([ys[0] - ys[1], ys[2] - ys[3]])
            
    
    for n in range(N):
        prog.AddConstraint(partial(relative_foot_constraint, context_index=n),
        lb=np.array([0, 0]), ub=np.array([np.inf, np.inf]), vars=q[:, n])
    """
    for n in range(N-1):
        for foot in range(4):
            prog.AddBoundingBoxConstraint(
                0, 4 * 9.81 * total_mass,
                contact_force[foot][2, n])
    # Periodicity constraints
    # if is_laterally_symmetric:
    #     # Joints
    #     def AddAntiSymmetricPair(a, b):
    #         prog.AddLinearEqualityConstraint(a[0] == -b[-1])
    #         prog.AddLinearEqualityConstraint(a[-1] == -b[0])
    #     def AddSymmetricPair(a, b):
    #         prog.AddLinearEqualityConstraint(a[0] == b[-1])
    #         prog.AddLinearEqualityConstraint(a[-1] == b[0])

    #     AddAntiSymmetricPair(q_view.front_left_hip_roll,
    #                          q_view.front_right_hip_roll)
    #     AddSymmetricPair(q_view.front_left_hip_pitch,
    #                      q_view.front_right_hip_pitch)
    #     AddSymmetricPair(q_view.front_left_knee, q_view.front_right_knee)
    #     AddAntiSymmetricPair(q_view.back_left_hip_roll,
    #                          q_view.back_right_hip_roll)
    #     AddSymmetricPair(q_view.back_left_hip_pitch,
    #                      q_view.back_right_hip_pitch)
    #     AddSymmetricPair(q_view.back_left_knee, q_view.back_right_knee)
    #     prog.AddLinearEqualityConstraint(q_view.rot1[0] == -q_view.rot1[-1])
    #     prog.AddLinearEqualityConstraint(v_view.rot1[0] == -v_view.rot1[-1])
    #     prog.AddLinearEqualityConstraint(q_view.body_y[0] == -q_view.body_y[-1])
    #     prog.AddLinearEqualityConstraint(q_view.body_z[0] == q_view.body_z[-1])
    #     # Body orientation must be in the xz plane:
    #     prog.AddBoundingBoxConstraint(0, 0, q_view.body_qx[[0,-1]])
    #     prog.AddBoundingBoxConstraint(0, 0, q_view.body_qz[[0,-1]])

    #     # Floating base velocity
    #     prog.AddLinearEqualityConstraint(v_view.body_vx[0] == v_view.body_vx[-1])
    #     prog.AddLinearEqualityConstraint(v_view.body_vy[0] == -v_view.body_vy[-1])
    #     prog.AddLinearEqualityConstraint(v_view.body_vz[0] == v_view.body_vz[-1])

    #     # CoM velocity
    #     prog.AddLinearEqualityConstraint(comdot[0,0] == comdot[0,-1])
    #     prog.AddLinearEqualityConstraint(comdot[1,0] == -comdot[1,-1])
    #     prog.AddLinearEqualityConstraint(comdot[2,0] == comdot[2,-1])

    # else:
    #     # Everything except body_x is periodic
    #     q_selector = PositionView([True]*nq)
    #     q_selector.body_x = False
    #     # make bridge periodic
    #     q_selector.rot1 = False
    #     prog.AddLinearConstraint(eq(q[q_selector,0], q[q_selector,-1]))
    #     prog.AddLinearConstraint(eq(v[:,0], v[:,-1]))

    # TODO: Set solver parameters (mostly to make the worst case solve times less bad)
    snopt = SnoptSolver().solver_id()
    if initial_guess is not None:
        print('Overriding initial guess to the provided')
        prog.SetInitialGuessForAllVariables(initial_guess)
    prog.SetSolverOption(snopt, 'Iterations Limits', 1e7 if running_as_notebook else 1)
    prog.SetSolverOption(snopt, 'Major Iterations Limit', 20000 if running_as_notebook else 1)
    major_feasibility_tolerance = 5e-4
    prog.SetSolverOption(snopt, 'Major Feasibility Tolerance', major_feasibility_tolerance)
    prog.SetSolverOption(snopt, 'Major Optimality Tolerance', 1e-4)
    prog.SetSolverOption(snopt, 'Superbasics limit', 20000)
    prog.SetSolverOption(snopt, 'Linesearch tolerance', 0.9)
    #prog.SetSolverOption(snopt, 'Print file', 'snopt.out')

    # TODO a few more costs/constraints from
    # from https://github.com/RobotLocomotion/LittleDog/blob/master/gaitOptimization.m
    print("starting solver")

    print('Check Satisfied at initial guess:', prog.CheckSatisfiedAtInitialGuess(prog.GetAllConstraints(), major_feasibility_tolerance))
    result = Solve(prog)
    print('Solver name:', result.get_solver_id().name())
    print('Solver result:', result.is_success())  # We expect this to be false if iterations are limited.
    print('Solver infeasible constraints:', result.GetInfeasibleConstraints(prog, major_feasibility_tolerance))
    print(result.GetInfeasibleConstraintNames(prog, major_feasibility_tolerance))
    def HalfStrideToFullStride(a):
        b = PositionView(np.copy(a))

        b.body_y = -a.body_y
        # Mirror quaternion so that roll=-roll, yaw=-yaw
        b.body_qx = -a.body_qx
        b.body_qz = -a.body_qz

        b.front_left_hip_roll = -a.front_right_hip_roll
        b.front_right_hip_roll = -a.front_left_hip_roll
        b.back_left_hip_roll = -a.back_right_hip_roll
        b.back_right_hip_roll = -a.back_left_hip_roll

        b.front_left_hip_pitch = a.front_right_hip_pitch
        b.front_right_hip_pitch = a.front_left_hip_pitch
        b.back_left_hip_pitch = a.back_right_hip_pitch
        b.back_right_hip_pitch = a.back_left_hip_pitch

        b.front_left_knee = a.front_right_knee
        b.front_right_knee = a.front_left_knee
        b.back_left_knee = a.back_right_knee
        b.back_right_knee = a.back_left_knee

        b.rot1 = -a.rot1

        return b


    # Animate trajectory
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyContextFromRoot(context)
    t_sol = np.cumsum(np.concatenate(([0],result.GetSolution(h))))
    q_sol = PiecewisePolynomial.FirstOrderHold(t_sol, result.GetSolution(q))
    visualizer.StartRecording()
    num_strides = 1
    t0 = t_sol[0]
    tf = t_sol[-1]
    T = tf*num_strides*(2.0 if is_laterally_symmetric else 1.0)
    for t in np.hstack((np.arange(t0, T, 1.0/32.0), T)):
        context.SetTime(t)
        stride = (t - t0) // (tf - t0)
        ts = (t - t0) % (tf - t0)
        qt = PositionView(q_sol.value(ts))
        if is_laterally_symmetric:
            if stride % 2 == 1:
                qt = HalfStrideToFullStride(qt)
                qt.body_x += stride_length/2.0
            stride = stride // 2
        qt.body_x += stride*stride_length
        plant.SetPositions(plant_context, qt[:])
        diagram.Publish(context)

    visualizer.StopRecording()
    visualizer.PublishRecording()
    return result

# Try them all!  The last two could use a little tuning.
gait_optimization('walking_trot', 0)
# for i in range(6):
#     result = gait_optimization('walking_trot', i * 0.01, result).GetSolution()
# gait_optimization('running_trot')
# gait_optimization('rotary_gallop')
# gait_optimization('bound')
# Out:
# [ 0.          0.00018405 -0.00953257]
# [[0.]
#  [0.]
#  [1.]]
# [[0.2 0.  0. ]
#  [0.  0.2 0. ]
#  [0.  0.  0.2]]
# q0 home positions: [ 0.     1.     0.     0.     0.     0.     0.     1.346  0.1    1.
#  -1.55  -0.1    1.    -1.55   0.1   -1.     1.55  -0.1   -1.     1.55 ]
# Entering MakeNamedViewPositions
# joint name front_left_hip_roll joint.num_positions 1
# joint name front_left_hip_pitch joint.num_positions 1
# joint name front_left_knee joint.num_positions 1
# joint name front_right_hip_roll joint.num_positions 1
# joint name front_right_hip_pitch joint.num_positions 1
# joint name front_right_knee joint.num_positions 1
# joint name back_left_hip_roll joint.num_positions 1
# joint name back_left_hip_pitch joint.num_positions 1
# joint name back_left_knee joint.num_positions 1
# joint name back_right_hip_roll joint.num_positions 1
# joint name back_right_hip_pitch joint.num_positions 1
# joint name back_right_knee joint.num_positions 1
# joint name rot1 joint.num_positions 1
# Exiting MakeNamedViewPositions
# ('rot1', 'body_qw', 'body_qx', 'body_qy', 'body_qz', 'body_x', 'body_y', 'body_z', 'front_left_hip_roll', 'front_left_hip_pitch', 'front_left_knee', 'front_right_hip_roll', 'front_right_hip_pitch', 'front_right_knee', 'back_left_hip_roll', 'back_left_hip_pitch', 'back_left_knee', 'back_right_hip_roll', 'back_right_hip_pitch', 'back_right_knee')
# starting solver
# Check Satisfied at initial guess: False
# Solver name: SNOPT/fortran
# Solver result: False
# Solver infeasible constraints: [<pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9347930>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc956cc30>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9236430>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b6830>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b6270>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b6370>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b6fb0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b6a70>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b6e30>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b6db0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b6470>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b64b0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b6a30>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b6530>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b6070>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b65f0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b62f0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b6570>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc91b63f0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc94349b0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434830>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc94346b0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434ab0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434930>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434770>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434b30>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434bb0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434cb0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434d30>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434cf0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434870>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434970>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc94348b0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434730>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc94348f0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434eb0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434f70>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434c70>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434bf0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434d70>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc94347f0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434b70>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434fb0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434c30>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc9434ef0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc943c6f0>, <pydrake.solvers.mathematicalprogram.Binding[Constraint] object at 0x7fedc943cdb0>, <pydrake.solvers.mat ...
# ['drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015483 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015496 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015726 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015765 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015897 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015401 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015478 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015458 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015440 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015424 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015412 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015397 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015347 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015336 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015336 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015335 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015335 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015334 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibody::UnitQuaternionConstraint[0]: 1.000000 <= 1.015333 <= 1.000000', 'drake::multibo ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=62851c10-b5c1-4bff-87dc-84099c2e318d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
